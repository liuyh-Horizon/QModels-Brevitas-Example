# %%
import torch
from torch import nn
from torch.nn import Module
import torch.nn.functional as F

# %%
import torchvision
from torchvision import datasets
from torchvision import transforms
from torch.autograd import Variable

# %%
import brevitas.nn as qnn
from brevitas.quant import Int8Bias as BiasQuant
from brevitas.export import FINNManager
from brevitas.export import StdQOpONNXManager

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
import time

# %%
start_time = time.time()

# %%
n_epochs = 3
batch_size_train = 64
batch_size_test = 1000
learning_rate = 0.01
momentum = 0.5
log_interval = 10

random_seed = 1
torch.backends.cudnn.enabled = False
torch.manual_seed(random_seed)

# %%
data_train = torchvision.datasets.MNIST('./data/', 
                                        train=True, download=True,
                                        transform=torchvision.transforms.Compose
                                        ([
                                            torchvision.transforms.ToTensor(),
                                            torchvision.transforms.Normalize((0.1307,), (0.3081,))
                                        ]))
data_test = torchvision.datasets.MNIST('./data/', 
                                       train=False, download=True,
                                       transform=torchvision.transforms.Compose
                                       ([
                                            torchvision.transforms.ToTensor(),
                                            torchvision.transforms.Normalize((0.1307,), (0.3081,))
                                       ]))

# %%
data_loader_train = torch.utils.data.DataLoader(dataset=data_train,
                                                batch_size=batch_size_train, 
                                                shuffle=True)

# %%
data_loader_test = torch.utils.data.DataLoader(dataset=data_test,
                                               batch_size=batch_size_test, 
                                               shuffle=True)

# %%
examples = enumerate(data_loader_test)
batch_idx, (example_data, example_targets) = next(examples)
example_data.shape
# Out:
# torch.Size([1000, 1, 28, 28])

# %%
fig = plt.figure()
for i in range(6):
  plt.subplot(2,3,i+1)
  plt.tight_layout()
  plt.imshow(example_data[i][0], cmap='gray', interpolation='none')
  plt.title("Ground Truth: {}".format(example_targets[i]))
  plt.xticks([])
  plt.yticks([])
fig

# %%
class LowPrecisionMLP(Module):
    def __init__(self):
        super(LowPrecisionMLP, self).__init__()
        self.quant_inp = qnn.QuantIdentity(
            bit_width=2, return_quant_tensor=True)
        self.fc1   = qnn.QuantLinear(
            1*28*28, 32, bias=True, weight_bit_width=8, bias_quant=BiasQuant, return_quant_tensor=True)
        self.relu1 = qnn.QuantReLU(
            bit_width=2, return_quant_tensor=True)
        self.fc2   = qnn.QuantLinear(
            32, 32, bias=True, weight_bit_width=8, bias_quant=BiasQuant, return_quant_tensor=True)
        self.relu2 = qnn.QuantReLU(
            bit_width=2, return_quant_tensor=True)
        self.fc3   = qnn.QuantLinear(
            32, 32, bias=True, weight_bit_width=8, bias_quant=BiasQuant, return_quant_tensor=True)
        self.relu3 = qnn.QuantReLU(
            bit_width=2, return_quant_tensor=True)
        self.fc4   = qnn.QuantLinear(
            32, 10, bias=False, weight_bit_width=8)

    def forward(self, x):
        out = self.quant_inp(x)
        out = out.reshape(out.shape[0], -1)
        out = self.relu1(self.fc1(out))
        out = self.relu2(self.fc2(out))
        out = self.relu3(self.fc3(out))
        out = self.fc4(out)
        return out

# %%
low_precision_mlp = LowPrecisionMLP()

# %%
cost=torch.nn.CrossEntropyLoss()

# %%
optimizer = torch.optim.Adam(low_precision_mlp.parameters())

# %%
# 卷积神经网络模型进行模型训练和参数优化的代码
n_epochs = 5
 
for epoch in range(n_epochs):
    running_loss = 0.0
    running_correct = 0
    print("Epoch  {}/{}".format(epoch, n_epochs))
    print("-"*10)
    for data in data_loader_train:
        X_train , y_train = data
        # 有GPU加下面这行，没有不用加
        # X_train, y_train = X_train.cuda(), y_train.cuda()
        X_train , y_train = Variable(X_train),Variable(y_train)
        # print(y_train)
        outputs = low_precision_mlp(X_train)
        # print(outputs)
        _,pred = torch.max(outputs.data,1)
        optimizer.zero_grad()
        loss = cost(outputs,y_train)
 
        loss.backward()
        optimizer.step()
        # running_loss += loss.data[0]
        running_loss += loss.item()
        running_correct += torch.sum(pred == y_train.data)
        # print("ok")
        # print("**************%s"%running_corrrect)
 
    print("train ok ")
    testing_correct = 0
    for data in data_loader_test:
        X_test,y_test = data
        # 有GPU加下面这行，没有不用加
        # X_test, y_test = X_test.cuda(), y_test.cuda()
        X_test,y_test = Variable(X_test),Variable(y_test)
        outputs = low_precision_mlp(X_test)
        _, pred = torch.max(outputs,1)
        testing_correct += torch.sum(pred == y_test.data)
        # print(testing_correct)
 
    print( "Loss is :{:.4f},Train Accuracy is:{:.4f}%,Test Accuracy is:{:.4f}".format(
                 running_loss / len(data_train),100 * running_correct / len(data_train),
                 100 * testing_correct / len(data_test)))
# Out:
# Epoch  0/5
# ----------
# train ok
# /opt/conda/conda-bld/pytorch_1591914855613/work/aten/src/ATen/native/BinaryOps.cpp:81: UserWarning: Integer division of tensors using div or / is deprecated, and in a future release div will perform true division as in Python 3. Use true_divide or floor_divide (// in Python) instead.
# Loss is :0.0089,Train Accuracy is:81.0000%,Test Accuracy is:90.0000
# Epoch  1/5
# ----------
# train ok
# Loss is :0.0042,Train Accuracy is:91.0000%,Test Accuracy is:92.0000
# Epoch  2/5
# ----------
# train ok
# Loss is :0.0033,Train Accuracy is:93.0000%,Test Accuracy is:93.0000
# Epoch  3/5
# ----------
# train ok
# Loss is :0.0029,Train Accuracy is:94.0000%,Test Accuracy is:93.0000
# Epoch  4/5
# ----------
# train ok
# Loss is :0.0025,Train Accuracy is:94.0000%,Test Accuracy is:94.0000

# %%
stop_time = time.time()
print("time is %s" %(stop_time-start_time))
# Out:
# time is 95.67242074012756

# %%
FINNManager.export(low_precision_mlp, input_shape=(1, 28, 28), export_path='finn_xxsfc_w8a2.onnx')
# Out:
# ir_version: 6
# producer_name: "pytorch"
# producer_version: "1.5"
# graph {
#   node {
#     input: "inp.1"
#     input: "12"
#     output: "13"
#     name: "MultiThreshold_1"
#     op_type: "MultiThreshold"
#     attribute {
#       name: "out_dtype"
#       s: "INT2"
#       type: STRING
#     }
#     domain: "finn.custom_op.general"
#   }
#   node {
#     input: "13"
#     input: "14"
#     output: "15"
#     name: "Add_3"
#     op_type: "Add"
#     domain: ""
#   }
#   node {
#     input: "15"
#     input: "16"
#     output: "17"
#     name: "Mul_5"
#     op_type: "Mul"
#   }
#   node {
#     input: "17"
#     output: "18"
#     name: "Shape_6"
#     op_type: "Shape"
#   }
#   node {
#     input: "18"
#     input: "19"
#     output: "20"
#     name: "Gather_8"
#     op_type: "Gather"
#     attribute {
#       name: "axis"
#       i: 0
#       type: INT
#     }
#   }
#   node {
#     input: "20"
#     output: "22"
#     name: "Unsqueeze_9"
#     op_type: "Unsqueeze"
#     attribute {
#       name: "axes"
#       ints: 0
#       type: INTS
#     }
#   }
#   node {
#     input: "22"
#     input: "72"
#     output: "24"
#     name: "Concat_10"
#     op_type: "Concat"
#     attribute {
#       name: "axis"
#       i: 0
#       type: INT
#     }
#   }
#   node {
#     input: "17"
#     input: "24"
#     output: "25"
#     name: "Reshape_11"
#     op_type: "Reshape"
#   }
#   node {
#     input: "25"
#     input: "26"
#     output: "28"
#     name: "MatMul_14"
#     op_type: "MatMul"
#     domain: ""
#   }
#   node {
#     input: "28"
#     input: "29"
#     output: "30"
#     name: "Mul_16"
#     op_type: "Mul"
#   }
#   node {
#     input: "30"
#     input: "31"
#     output: "32"
#     name: "Div_18"
#     op_type: "Div"
#     domain: ""
#   }
#   node {
#     input: "32"
#     input: "27"
#     output: "33"
#     name: "Add_19"
#     op_type: "Add"
#     domain: ""
#   }
#   node {
#     input: "33"
#     input: "34"
#     output: "35"
#     name: "Mul_21"
#     op_type: "Mul"
#   }
#   node {
#     input: "35"
#     input: "36"
#     output: "37"
#     name: "MultiThreshold_23"
#     op_type: "MultiThreshold"
#     attribute {
#       name: "out_dtype"
#       s: "UINT2"
#       type: STRING
#     }
#     domain: "finn.custom_op.general"
#   }
#   node {
#     input: "37"
#     input: "38"
#     output: "39"
#     name: "Mul_25"
#     op_type: "Mul"
#   }
#   node {
#     input: "39"
#     input: "40"
#     output: "42"
#     name: "MatMul_28"
#     op_type: "MatMul"
#     domain: ""
#   }
#   node {
#     input: "42"
#     input: "43"
#     output: "44"
#     name: "Mul_30"
#     op_type: "Mul"
#   }
#   node {
#     input: "44"
#     input: "45"
#     output: "46"
#     name: "Div_32"
#     op_type: "Div"
#     domain: ""
#   }
#   node {
#     input: "46"
#     input: "41"
#     output: "47"
#     name: "Add_33"
#     op_type: "Add"
#     domain: ""
#   }
#   node {
#     input: "47"
#     input: "48"
#     output: "49"
#     name: "Mul_35"
#     op_type: "Mul"
#   }
#   node {
#     input: "49"
#     input: "50"
#     output: "51"
#     name: "MultiThreshold_37"
#     op_type: "MultiThreshold"
#     attribute {
#       name: "out_dtype"
#       s: "UINT2"
#       type: STRING
#     }
#     domain: "finn.custom_op.general"
#   }
#   node {
#     input: "51"
#     input: "52"
#     output: "53"
#     name: "Mul_39"
#     op_type: "Mul"
#   }
#   node {
#     input: "53"
#     input: "54"
#     output: "56"
#     name: "MatMul_42"
#     op_type: "MatMul"
#     domain: ""
#   }
#   node {
#     input: "56"
#     input: "57"
#     output: "58"
#     name: "Mul_44"
#     op_type: "Mul"
#   }
#   node {
#     input: "58"
#     input: "59"
#     output: "60"
#     name: "Div_46"
#     op_type: "Div"
#     domain: ""
#   }
#   node {
#     input: "60"
#     input: "55"
#     output: "61"
#     name: "Add_47"
#     op_type: "Add"
#     domain: ""
#   }
#   node {
#     input: "61"
#     input: "62"
#     output: "63"
#     name: "Mul_49"
#     op_type: "Mul"
#   }
#   node {
#     input: "63"
#     input: "64"
#     output: "65"
#     name: "MultiThreshold_51"
#     op_type: "MultiThreshold"
#     attribute {
#       name: "out_dtype"
#       s: "UINT2"
#       type: STRING
#     }
#     domain: "finn.custom_op.general"
#   }
#   node {
#     input: "65"
#     input: "66"
#     output: "67"
#     name: "Mul_53"
#     op_type: "Mul"
#   }
#   node {
#     input: "67"
#     input: "68"

#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 10
#           }
#         }
#       }
#     }
#   }
#   quantization_annotation {
#     tensor_name: "26"
#     quant_parameter_tensor_names {
#       key: "finn_datatype"
#       value: "INT8"
#     }
#   }
#   quantization_annotation {
#     tensor_name: "27"
#     quant_parameter_tensor_names {
#       key: "finn_datatype"
#       value: "INT8"
#     }
#   }
#   quantization_annotation {
#     tensor_name: "40"
#     quant_parameter_tensor_names {
#       key: "finn_datatype"
#       value: "INT8"
#     }
#   }
#   quantization_annotation {
#     tensor_name: "41"
#     quant_parameter_tensor_names {
#       key: "finn_datatype"
#       value: "INT8"
#     }
#   }
#   quantization_annotation {
#     tensor_name: "54"
#     quant_parameter_tensor_names {
#       key: "finn_datatype"
#       value: "INT8"
#     }
#   }
#   quantization_annotation {
#     tensor_name: "55"
#     quant_parameter_tensor_names {
#       key: "finn_datatype"
#       value: "INT8"
#     }
#   }
#   quantization_annotation {
#     tensor_name: "68"
#     quant_parameter_tensor_names {
#       key: "finn_datatype"
#       value: "INT8"
#     }
#   }
# }
# opset_import {
#   domain: ""
#   version: 9
# }
# opset_import {
#   domain: "finn.custom_op.general"
#   version: 1
# }
# opset_import {
#   domain: "{DOMAIN_STRING}"
#   version: 1
# }

# %%
StdQOpONNXManager.export(low_precision_mlp, input_shape=(1, 28, 28), export_path='onnx_xxsfc_w8a2.onnx')
# Out:
# ir_version: 6
# producer_name: "pytorch"
# producer_version: "1.5"
# graph {
#   node {
#     output: "12"
#     name: "Constant_0"
#     op_type: "Constant"
#     attribute {
#       name: "value"
#       t {
#         dims: 28
#         dims: 3
#         data_type: 1
#         raw_data: "\257\n\020\300>\016@\277@\016@?\257\n\020\300>\016@\277@\016@?\257\n\020\300>\016@\277@\016@?\257\n\020\300>\016@\277@\016@?\257\n\020\300>\016@\277@\016@?\257\n\020\300>\016@\277@\016@?\257\n\020\300>\016@\277@\016@?\257\n\020\300>\016@\277@\016@?\257\n\020\300>\016@\277@\016@?\257\n\020\300>\016@\277@\016@?\257\n\020\300>\016@\277@\016@?\257\n\020\300>\016@\277@\016@?\257\n\020\300>\016@\277@\016@?\257\n\020\300>\016@\277@\016@?\257\n\020\300>\016@\277@\016@?\257\n\020\300>\016@\277@\016@?\257\n\020\300>\016@\277@\016@?\257\n\020\300>\016@\277@\016@?\257\n\020\300>\016@\277@\016@?\257\n\020\300>\016@\277@\016@?\257\n\020\300>\016@\277@\016@?\257\n\020\300>\016@\277@\016@?\257\n\020\300>\016@\277@\016@?\257\n\020\300>\016@\277@\016@?\257\n\020\300>\016@\277@\016@?\257\n\020\300>\016@\277@\016@?\257\n\020\300>\016@\277@\016@?\257\n\020\300>\016@\277@\016@?"
#       }
#       type: TENSOR
#     }
#   }
#   node {
#     input: "inp.1"
#     input: "12"
#     output: "13"
#     name: "MultiThreshold_1"
#     op_type: "MultiThreshold"
#     attribute {
#       name: "out_dtype"
#       s: "INT2"
#       type: STRING
#     }
#     domain: "finn.custom_op.general"
#   }
#   node {
#     output: "14"
#     name: "Constant_2"
#     op_type: "Constant"
#     attribute {
#       name: "value"
#       t {
#         data_type: 1
#         raw_data: "\000\000\000\300"
#       }
#       type: TENSOR
#     }
#   }
#   node {
#     input: "13"
#     input: "14"
#     output: "15"
#     name: "Add_3"
#     op_type: "Add"
#   }
#   node {
#     output: "16"
#     name: "Constant_4"
#     op_type: "Constant"
#     attribute {
#       name: "value"
#       t {
#         data_type: 1
#         raw_data: "?\016\300?"
#       }
#       type: TENSOR
#     }
#   }
#   node {
#     input: "15"
#     input: "16"
#     output: "17"
#     name: "Mul_5"
#     op_type: "Mul"
#   }
#   node {
#     input: "17"
#     output: "18"
#     name: "Shape_6"
#     op_type: "Shape"
#   }
#   node {
#     output: "19"
#     name: "Constant_7"
#     op_type: "Constant"
#     attribute {
#       name: "value"
#       t {
#         data_type: 7
#         raw_data: "\000\000\000\000\000\000\000\000"
#       }
#       type: TENSOR
#     }
#   }
#   node {
#     input: "18"
#     input: "19"
#     output: "20"
#     name: "Gather_8"
#     op_type: "Gather"
#     attribute {
#       name: "axis"
#       i: 0
#       type: INT
#     }
#   }
#   node {
#     input: "20"
#     output: "22"
#     name: "Unsqueeze_9"
#     op_type: "Unsqueeze"
#     attribute {
#       name: "axes"
#       ints: 0
#       type: INTS
#     }
#   }
#   node {
#     input: "22"
#     input: "72"
#     output: "24"
#     name: "Concat_10"
#     op_type: "Concat"
#     attribute {
#       name: "axis"
#       i: 0
#       type: INT
#     }
#   }
#   node {
#     input: "17"
#     input: "24"
#     output: "25"
#     name: "Reshape_11"
#     op_type: "Reshape"
#   }
#   node {
#     output: "26"
#     name: "Constant_12"
#     op_type: "Constant"
#     attribute {
#       name: "value"
#       t {
#         dims:
000\000\200?\000\000\200?\000\000\200?\000\000\200?\000\000\300@\000\000\300@\000\000\200\277\000\000\000@\000\000\000\300\000\000\200?\000\000\200?\000\000\340\300\000\000\000@\000\000\340@\000\000\300\300\000\000\200?\000\000\200@\000\000\200@\000\000\000@\000\000\200@\000\000\200@\000\000\200\300\000\000@\300\000\000\300\300\000\000\000@\000\000\200@\000\000\000\300\000\000@\300\000\000\300@\000\000\000@\000\000\200@\000\000\240\300\000\000@\300\000\000\200\277\000\000\200\300\000\000\300\300\000\000\200\300\000\000\200\277\000\000\240\300\000\000\200@\000\000@@\000\000\200@\000\000\000\300\000\000\240@\000\000@@\000\000\300\300\000\000\200@\000\000\300@\000\000\000\000\000\000\240\300\000\000\000\300\000\000\300\300\000\000\000\000\000\000@\300\000\000\200@\000\000\200@\000\000\240@\000\000\200?\000\000\200\300\000\000@\300\000\000\240@\000\000\240\300\000\000\000\300\000\000\ ...
#       }
#       type: TENSOR
#     }
#   }
#   node {
#     output: "27"
#     name: "Constant_13"
#     op_type: "Constant"
#     attribute {
#       name: "value"
#       t {
#         dims: 32
#         data_type: 1
#         raw_data: "\000\000\300A\000\000\000@\000\000\350A\000\000\200\277\000\000@A\000\000pA\000\000\340\300\000\000\210A\000\000P\301\000\000 \301\000\000\000\000\000\000\210A\000\000\270A\000\000@@\000\000\360A\000\000\200@\000\000\240@\000\000\000A\000\000 \301\000\000PA\000\000 A\000\000@A\000\000PA\000\0000A\000\000pA\000\000\200\300\000\000\200\300\000\000\020A\000\000\220A\000\000\230A\000\000\004B\000\000$B"
#       }
#       type: TENSOR
#     }
#   }
#   node {
#     input: "25"
#     input: "26"
#     output: "28"
#     name: "MatMul_14"
#     op_type: "MatMul"
#     attribute {
#       name: "weight_qnt"
#       s: "INT8"
#       type: STRING
#     }
#     domain: "finn.custom_op.general"
#   }
#   node {
#     output: "29"
#     name: "Constant_15"
#     op_type: "Constant"
#     attribute {
#       name: "value"
#       t {
#         data_type: 1
#         raw_data: "\242\311\254;"
#       }
#       type: TENSOR
#     }
#   }
#   node {
#     input: "28"
#     input: "29"
#     output: "30"
#     name: "Mul_16"
#     op_type: "Mul"
#   }
#   node {
#     output: "31"
#     name: "Constant_17"
#     op_type: "Constant"
#     attribute {
#       name: "value"
#       t {
#         dims: 1
#         data_type: 1
#         raw_data: "\327\240\001<"
#       }
#       type: TENSOR
#     }
#   }
#   node {
#     input: "30"
#     input: "31"
#     output: "32"
#     name: "Div_18"
#     op_type: "Div"
#   }
#   node {
#     input: "32"
#     input: "27"
#     output: "33"
#     name: "Add_19"
#     op_type: "Add"
#     attribute {
#       name: "bias_qnt"
#       s: "INT8"
#       type: STRING
#     }
#     domain: "{DOMAIN_STRING}"
#   }
#   node {
#     output: "34"
#     name: "Constant_20"
#     op_type: "Constant"
#     attribute {
#       name: "value"
#       t {
#         dims: 1
#         data_type: 1
#         raw_data: "\327\240\001<"
#       }
#       type: TENSOR
#     }
#   }
#   node {
#     input: "33"
#     input: "34"
#     output: "35"
#     name: "Mul_21"
#     op_type: "Mul"
#   }
#   node {
#     output: "36"
#     name: "Constant_22"
#     op_type: "Constant"
#     attribute {
#       name: "value"
#       t {
#         dims: 32
#         dims: 3
#         data_type: 1
#         raw_data: "u\253\220?0\001Y@R\326\264@u\253\220?0\001Y@R\326\264@u\253\220?0\001Y@R\326\264@u\253\220?0\001Y@R\326\264@u\253\220?0\001Y@R\326\264@u\253\220?0\001Y@R\326\264@u\253\220?0\001Y@R\326\264@u\253\220?0\001Y@R\326\264@u\253\220?0\001Y@R\326\264@u\253\220?0\001Y@R\326\264@u\253\220?0\001Y@R\326\264@u\253\220?0\001Y@R\326\264@u\253\220?0\001Y@R\326\264@u\253\220?0\001Y@R\326\264@u\253\220?0\001Y@R\326\264@u\253\220?0\001Y@R\326\264@u\253\220?0\001Y@R\326\264@u\253\220?0\001Y@R\326\264@u\253\220?0\001Y@R\326\264@u\253\220?0\001Y@R\326\264@u\253\220?0\001Y@R\326\264@u\253\220?0\001Y@R\326\264@u\253\220?0\001Y@R\326\264@u\253\220?0\001Y@R\326\264@u\253\220?0\001Y@R\326\264@u\253\220?0\001Y@R\326\264@u\253\220?0\001Y@R\326\264@u\253\220?0\001Y@R\326\264@u\253\220?0\001Y@R\326\264@u\253\220?0\001Y@R\326\264@u\253\220?0\001Y@R\326\264@u\253\220?0\001Y@R\326\264@"
#       }
#       type: TENSOR
#     }
#   }
#   node {
#     input: "35"
#     input: "36"
#     output: "37"
#     name: "MultiThreshold_23"
#     op_type: "MultiThreshold"
#     attribute {
#       name: "out_dtype"
#       s: "UINT2"
#       type: STRING
#     }
#     domain: "finn.custom_op.general"
#   }
#   node {
#     output: "38"
#     name: "Constant_24"
#     op_type: "Constant"
#     attribute {
#       name: "value"
#       t {
#         data_type: 1
#         raw_data: "u\253\020@"
#       }
#       type: TENSOR
#     }
#   }
#   node {
#     input:
\300\000\000@A\000\000PB\000\000\250\301\000\000\340A\000\000\000\000\000\000@A\000\000x\302\000\000\230\301\000\000$B\000\000\370A\000\000\340\301\000\000\240\301\000\000\220\302\000\000\000B\000\0000A\000\000(\302\000\000\200A\000\000 \302\000\000|B\000\000\004B\000\000\034\302\000\000PA\000\000\340\300\000\000HB\000\000pA\000\000\010B\000\000\250\302\000\000\240\300\000\0004B\000\000\340@\000\000\020\301\000\000\310A\000\000\200\301\000\000\300\300\000\000\310A\000\000PA\000\000\020\302\000\0000\301\000\000\330\301\000\000\024\302\000\000\204B\000\0000B\000\000\260\301\000\000XB\000\0000A\000\000,B\000\000PA\000\000\250\301\000\000\340\300\000\0004\302\000\000\202B\000\000\000\300\000\000<B\000\000pA\000\000l\302\000\000\210A\000\000\240\300\000\000\232B\000\000\020\302\000\000\000A\000\000\200\300\000\000\010\302\000\000\010\302\000\000\302\302\000\000\340@\000\000l\302\000\000hB\000\000\000@\000\000\270\301\000\000\030B\000\000@\302\000\000\240\301\000\000T\302\000\000\214B\000\000\020A\000\000\230A\000\000@\301\000\000\220\301\000\000\244B\000\000\004\302\000\000\000\300\000\000H\302\000\000\010B\000\000PA\000\000\014B\000\000 \302\000\0008\302\000\000\250A\000\000\340@\000\000\300\300\000\000\340A\000\000\000\302\000\000\0 ...
#       }
#       type: TENSOR
#     }
#   }
#   node {
#     output: "41"
#     name: "Constant_27"
#     op_type: "Constant"
#     attribute {
#       name: "value"
#       t {
#         dims: 32
#         data_type: 1
#         raw_data: "\000\000P\301\000\000\260A\000\000\270A\000\0000\301\000\000`A\000\000\000A\000\000pA\000\000pA\000\000\000\300\000\000\220A\000\000@\300\000\000\270A\000\000@A\000\000\200A\000\000@\301\000\000\270A\000\0000\301\000\000\000A\000\000\240@\000\000\300@\000\000\000@\000\000\200A\000\000p\301\000\000 A\000\000PA\000\000\340@\000\000\200?\000\000\200?\000\000\360A\000\000\000\000\000\000pA\000\000`A"
#       }
#       type: TENSOR
#     }
#   }
#   node {
#     input: "39"
#     input: "40"
#     output: "42"
#     name: "MatMul_28"
#     op_type: "MatMul"
#     attribute {
#       name: "weight_qnt"
#       s: "INT8"
#       type: STRING
#     }
#     domain: "finn.custom_op.general"
#   }
#   node {
#     output: "43"
#     name: "Constant_29"
#     op_type: "Constant"
#     attribute {
#       name: "value"
#       t {
#         data_type: 1
#         raw_data: "R\014\243;"
#       }
#       type: TENSOR
#     }
#   }
#   node {
#     input: "42"
#     input: "43"
#     output: "44"
#     name: "Mul_30"
#     op_type: "Mul"
#   }
#   node {
#     output: "45"
#     name: "Constant_31"
#     op_type: "Constant"
#     attribute {
#       name: "value"
#       t {
#         dims: 1
#         data_type: 1
#         raw_data: "DH8<"
#       }
#       type: TENSOR
#     }
#   }
#   node {
#     input: "44"
#     input: "45"
#     output: "46"
#     name: "Div_32"
#     op_type: "Div"
#   }
#   node {
#     input: "46"
#     input: "41"
#     output: "47"
#     name: "Add_33"
#     op_type: "Add"
#     attribute {
#       name: "bias_qnt"
#       s: "INT8"
#       type: STRING
#     }
#     domain: "{DOMAIN_STRING}"
#   }
#   node {
#     output: "48"
#     name: "Constant_34"
#     op_type: "Constant"
#     attribute {
#       name: "value"
#       t {
#         dims: 1
#         data_type: 1
#         raw_data: "DH8<"
#       }
#       type: TENSOR
#     }
#   }
#   node {
#     input: "47"
#     input: "48"
#     output: "49"
#     name: "Mul_35"
#     op_type: "Mul"
#   }
#   node {
#     output: "50"
#     name: "Constant_36"
#     op_type: "Constant"
#     attribute {
#       name: "value"
#       t {
#         dims: 32
#         dims: 3
#         data_type: 1
#         raw_data: "?H\235?^\354k@O\232\304@?H\235?^\354k@O\232\304@?H\235?^\354k@O\232\304@?H\235?^\354k@O\232\304@?H\235?^\354k@O\232\304@?H\235?^\354k@O\232\304@?H\235?^\354k@O\232\304@?H\235?^\354k@O\232\304@?H\235?^\354k@O\232\304@?H\235?^\354k@O\232\304@?H\235?^\354k@O\232\304@?H\235?^\354k@O\232\304@?H\235?^\354k@O\232\304@?H\235?^\354k@O\232\304@?H\235?^\354k@O\232\304@?H\235?^\354k@O\232\304@?H\235?^\354k@O\232\304@?H\235?^\354k@O\232\304@?H\235?^\354k@O\232\304@?H\235?^\354k@O\232\304@?H\235?^\354k@O\232\304@?H\235?^\354k@O\232\304@?H\235?^\354k@O\232\304@?H\235?^\354k@O\232\304@?H\235?^\354k@O\232\304@?H\235?^\354k@O\232\304@?H\235?^\354k@O\232\304@?H\235?^\354k@O\232\304@?H\235?^\354k@O\232\304@?H\235?^\354k@O\232\304@?H\235?^\354k@O\232\304@?H\235?^\354k@O\232\304@"
#       }
#       type: TENSOR
#     }
#   }
#   node {
#     input:
\000\000@\301\000\000\250\301\000\000PA\000\000\240\301\000\000P\302\000\0000A\000\0004\302\000\000\300A\000\000 A\000\000 B\000\000\210\301\000\000d\302\000\000\210B\000\000\300A\000\000\200A\000\000@\301\000\000\236\302\000\000h\302\000\000\260B\000\000(B\000\000\000@\000\000\014\302\000\000\224B\000\000\024B\000\000\240@\000\000\206B\000\000\260\301\000\000\020\301\000\000\200\301\000\000\230\301\000\000\004B\000\000\250\301\000\000\350\301\000\000\024B\000\000pB\000\000,\302\000\000\340A\000\000\260A\000\000 B\000\000(\302\000\000\210\301\000\000\250A\000\000\014B\000\000,\302\000\000PB\000\000\340\301\000\000\034B\000\000\200\302\000\000\020\301\000\0000\301\000\000\220A\000\000X\302\000\000@B\000\000\260A\000\000\334B\000\000 \302\000\000\000\302\000\000\226B\000\000\234B\000\000\222B\000\000\300A\000\000\310A\000\0004\302\000\000\212B\000\000@\301\000\000\370\301\000\000(\302\000\000\000\300\000\000\200A\000\000\000\300\000\000\004B\000\000\240@\000\000\232B\000\000p\301\000\000\340\301\000\000\260A\000\000P\302\000\000\370\301\000\000@\301\000\000H\302\000\000,B\000\000HB\000\000\200A\000\000tB\000\000\206B\000\000\330A\000\000\204B\000\000\320A\000\000\020A\000\000\000\300\000\000\200\301\000\000\320\301\000\000\212\302\000\000\250\302\000\000$\302\000\000 B\000\000\270A\000\000pA\000\000\010B\000\0004B\000\000$B\000\000\200\277\000\000`A\000\0000A\000\000T\302\000\000\320A\000\000\000\000\000\0000B\000\000\236B\000\000\220A\000\000\220A\000\000\242\302\000\000\250\301\000\000\310\301\000\000\350A\000\000\000\300\000\000\260A\0 ...
#       }
#       type: TENSOR
#     }
#   }
#   node {
#     output: "55"
#     name: "Constant_41"
#     op_type: "Constant"
#     attribute {
#       name: "value"
#       t {
#         dims: 32
#         data_type: 1
#         raw_data: "\000\000 A\000\000\200?\000\000\020A\000\000\200\300\000\000\300\301\000\000\000@\000\000\270A\000\000\340@\000\000\200\300\000\000\000\000\000\000@@\000\000@A\000\000pA\000\000\350A\000\000p\301\000\000\020A\000\000\000A\000\000@@\000\000\230\301\000\000\200?\000\000\270A\000\000\034B\000\000@A\000\000\260A\000\0000\301\000\000\210A\000\000\020A\000\000\240\301\000\000\230A\000\000\000@\000\000`A\000\000\260A"
#       }
#       type: TENSOR
#     }
#   }
#   node {
#     input: "53"
#     input: "54"
#     output: "56"
#     name: "MatMul_42"
#     op_type: "MatMul"
#     attribute {
#       name: "weight_qnt"
#       s: "INT8"
#       type: STRING
#     }
#     domain: "finn.custom_op.general"
#   }
#   node {
#     output: "57"
#     name: "Constant_43"
#     op_type: "Constant"
#     attribute {
#       name: "value"
#       t {
#         data_type: 1
#         raw_data: "\311\271\206;"
#       }
#       type: TENSOR
#     }
#   }
#   node {
#     input: "56"
#     input: "57"
#     output: "58"
#     name: "Mul_44"
#     op_type: "Mul"
#   }
#   node {
#     output: "59"
#     name: "Constant_45"
#     op_type: "Constant"
#     attribute {
#       name: "value"
#       t {
#         dims: 1
#         data_type: 1
#         raw_data: "\353\213%<"
#       }
#       type: TENSOR
#     }
#   }
#   node {
#     input: "58"
#     input: "59"
#     output: "60"
#     name: "Div_46"
#     op_type: "Div"
#   }
#   node {
#     input: "60"
#     input: "55"
#     output: "61"
#     name: "Add_47"
#     op_type: "Add"
#     attribute {
#       name: "bias_qnt"
#       s: "INT8"
#       type: STRING
#     }
#     domain: "{DOMAIN_STRING}"
#   }
#   node {
#     output: "62"
#     name: "Constant_48"
#     op_type: "Constant"
#     attribute {
#       name: "value"
#       t {
#         dims:
000\000\252\302\000\000\200\300\000\000\010\302\000\000\360\302\000\000DB\000\000\320\302\000\000\240\300\000\000\000\300\000\000\340A\000\000\360\301\000\000\224\302\000\0000\301\000\000\024B\000\000\240B\000\000\360A\000\0000\301\000\000\\\302\000\000\300A\000\000\360\301\000\000\250\302\000\000\204B\000\000p\301\000\000\\B\000\000\030B\000\000H\302\000\000\020\302\000\000\310\301\000\000\300A\000\000\200@\000\000\\B\000\000d\302\000\000LB\000\000\014B\000\000\246\302\000\000\004B\000\000\232\302\000\000\340\300\000\000\004B\000\000\250A\000\000<\302\000\000@\302\000\000\020A\000\000@@\000\000\000\000\000\000\004\302\000\000 B\000\000\330A\000\0008B\000\000\000A\000\000|B\000\000\010B\000\000\300A\000\000\306\302\000\000\326\302\000\000\310\301\000\000\360\301\000\000\000B\000\000LB\000\000$B\000\000\376\302\000\000\250A\000\000\004\302\000\000DB\000\000$\302\000\000\276\302\000\000(B\000\000\020\302\000\000\202B\000\000\200?\000\000\270A\000\000\214\302\000\000\\\302\000\000\210B\000\000\240A\000\000\226\302\000\000\340\300\000\000\260\301\000\000\000\000\000\000LB\000\000\320A\000\000\200@\000\000@\302\000\000\216\302\000\0004B\000\000\300\301\000\000\260\301\000\000\240\301\000\000\210\302\000\000\200B\000\000\010B\000\000\\\302\000\000TB\000\000\010\302\000\000\206\302\000\000\250\301\000\000\220A\000\000\202B\000\000p\302\000\000\320A\000\000xB\000\000\000\000\000\000@\302\000\000\302\302\000\000@\301\000\000<\302\000\000\200@\000\000 \301\000\000\350\301\000\000`A\000\000\242\302\000\000\222B\000\000\340@\000\000\020A\000\000\200\300\000\000 A\000\000\370A\000\000\204\302\000\000(B\000\000P\302\000\000\\B\000\000$\302\000\000TB\000\000\300\301\000\000\242\302\000\000xB\000\000\242B\000\000P\302\000\000D\302\000\000\250A\000\000l\302\000\000\370\301\000\000\210\302\000\000\224\302\000\000\206B\000\000h\302\000\000H\302\000\000\370A\000\000\010B\00 ...
#       }
#       type: TENSOR
#     }
#   }
#   node {
#     input: "67"
#     input: "68"
#     output: "69"
#     name: "MatMul_55"
#     op_type: "MatMul"
#     attribute {
#       name: "weight_qnt"
#       s: "INT8"
#       type: STRING
#     }
#     domain: "finn.custom_op.general"
#   }
#   node {
#     output: "70"
#     name: "Constant_56"
#     op_type: "Constant"
#     attribute {
#       name: "value"
#       t {
#         data_type: 1
#         raw_data: "\327\353G;"
#       }
#       type: TENSOR
#     }
#   }
#   node {
#     input: "69"
#     input: "70"
#     output: "71"
#     name: "Mul_57"
#     op_type: "Mul"
#   }
#   name: "torch-jit-export"
#   initializer {
#     dims: 1
#     data_type: 7
#     name: "72"
#     raw_data: "\377\377\377\377\377\377\377\377"
#   }
#   input {
#     name: "inp.1"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 28
#           }
#           dim {
#             dim_value: 28
#           }
#         }
#       }
#     }
#   }
#   input {
#     name: "72"
#     type {
#       tensor_type {
#         elem_type: 7
#         shape {
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   output {
#     name: "71"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 10
#           }
#         }
#       }
#     }
#   }
# }
# opset_import {
#   domain: ""
#   version: 11
# }
# opset_import {
#   domain: "finn.custom_op.general"
#   version: 1
# }
# opset_import {
#   domain: "{DOMAIN_STRING}"
#   version: 1
# }
