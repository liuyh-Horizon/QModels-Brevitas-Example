# %%
import torchvision
from torchvision import datasets
from torchvision import transforms
from torch.autograd import Variable

# %%
data_train = torchvision.datasets.MNIST('./data/', 
                                        train=True, download=True,
                                        transform=torchvision.transforms.Compose
                                        ([
                                            torchvision.transforms.ToTensor(),
                                            #torchvision.transforms.Normalize((0.1307,), (0.3081,))
                                            torchvision.transforms.Normalize((0.5,), (0.5,))
                                        ]))
data_test = torchvision.datasets.MNIST('./data/', 
                                       train=False, download=True,
                                       transform=torchvision.transforms.Compose
                                       ([
                                            torchvision.transforms.ToTensor(),
                                            #torchvision.transforms.Normalize((0.1307,), (0.3081,))
                                            torchvision.transforms.Normalize((0.5,), (0.5,))
                                       ]))

# %%
import torch

batch_size_train = 64
batch_size_test = 1000

data_loader_train = torch.utils.data.DataLoader(dataset=data_train,
                                                batch_size=batch_size_train, 
                                                shuffle=True)

data_loader_test = torch.utils.data.DataLoader(dataset=data_test,
                                               batch_size=batch_size_test, 
                                               shuffle=True)

# %%
examples = enumerate(data_loader_train)
batch_idx, (example_data, example_targets) = next(examples)
print(example_data[0][0])
example_data[0][0].shape
# Out:
# tensor([[-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#          -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#          -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#          -1.0000, -1.0000, -1.0000, -1.0000],
#         [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#          -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#          -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#          -1.0000, -1.0000, -1.0000, -1.0000],
#         [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#          -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -0.8588,  1.0000,  0.0667,
#          -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#          -1.0000, -1.0000, -1.0000, -1.0000],
#         [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#          -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -0.2392,  0.9922,  0.9686,
#          -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#          -1.0000, -1.0000, -1.0000, -1.0000],
#         [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#          -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,  0.5137,  0.9922,  0.6549,
#          -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#          -1.0000, -1.0000, -1.0000, -1.0000],
#         [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#          -1.0000, -1.0000, -1.0000, -1.0000, -0.9529,  0.6157,  0.9922, -0.3804,
#          -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#          -1.0000, -1.0000, -1.0000, -1.0000],
#         [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#          -1.0000, -1.0000, -1.0000, -1.0000,  0.1608,  0.9922,  0.9765, -0.4902,
#          -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#          -1.0000, -1.0000, -1.0000, -1.0000],
#         [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#          -1.0000, -1.0000, -1.0000, -1.0000,  0.5843,  0.9922,  0.8275, -1.0000,
#          -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#          -1.0000, -1.0000, -1.0000, -1.0000],
#         [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#          -1.0000, -1.0000, -1.0000, -1.0000,  0.5843,  0.9922,  0.1608, -1.0000,
#          -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#          -1.0000, -1.0000, -1.0000, -1.0000],
#         [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#          -1.0000, -1.0000, -1.0000, -0.4510,  0.8902,  0.9922, -0.4510, -1.0000,
#          -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#          -1.0000, -1.0000, -1.0000, -1.0000],
#         [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#          -1.0000, -1.0000, -1.0000,  0.6549,  0.9922,  0.9843, -0.4667, -1.0000,
#          -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#          -1.0000, -1.0000, -1.0000, -1.0000],
#         [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#          -1.0000, -1.0000, -1.0000,  0.6549,  0.9922,  0.6157, -1.0000, -1.0000,
#          -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#          -1.0000, -1.0000, -1.0000, -1.0000],
#         [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#          -1.0000, -1.0000, -0.8902,  0.7647,  0.9922, -0.0431, -1.0000, -1.0000,
#          -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#          -1.0000, -1.0000, -1.0000, -1.0000],
#         [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#          -1.0000, -1.0000, -0.6549,  0.9922,  0.9922, -0.5216, -1.0000, -0.8039,
#           0.0039,  0.2392,  0.0667, -0.7490, -1.0000, -1.0000, -1.0000, -1.0000,
#          -1.0000, -1.0000, -1.0000, -1.0000],
#         [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#          -1.0000, -1.0000, -0.4824,  0.9922,  0.9922,  0.6471,  0.8588,  0.9059,
#           0.9922,  0.9922,  0.9922,  0.9137, -0.1686, -1.0000, -1.0000, -1.0000,
#          -1.0000, -1.0000, -1.0000, -1.0000],
#         [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#          -1.0000, -1.0000,  0.1765,  0.9922,  0.9922,  0.9922,  0.9765,  0.0980,
#          -0.5529, -0.6078,  0.0510,  0.9451,  0.9529, -0.5451, -1.0000, -1.0000,
#          -1.0000, -1.0000, -1.0000, -1.0000],
#         [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#          -1.0000, -1.0000,  0.7176,  0.9922,  0.9922,  0.4431, -0.5451, -1.0000,
#          -1.0000, -1.0000, -1.0000,  0.1922,  0.9922,  0.0275, -1.0000, -1.0000,
#          -1.0000, -1.0000, -1.0000, -1.0000],
#         [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#          -1.0000, -1.0000,  0.6235,  0.9922,  0.8196, -0.9137, -1.0000, -1.0000,
#          -1.0000, -1.0000, -1.0000,  0.1922,  0.9922, -0.0667, -1.0000, -1.0000,
#          -1.0000, -1.0000, -1.0000, -1.0000],
#         [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#          -1.0000, -1.0000,  0.0275,  0.9922,  0.8039, -0.9451, -1.0000, -1.0000,
#          -1.0000, -0.9373, -0.2157,  0.9451,  0.8353, -0.8118, -1.0000, -1.0000,
#          -1.0000, -1.0000, -1.0000, -1.0000],
#         [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#          -1.0000, -1.0000, -0.0118,  0.9922,  0.9922,  0.0980, -0.1686, -0.1686,
#          -0.1686,  0.6235,  0.9922,  0.9922,  0.0745, -1.0000, -1.0000, -1.0000,
#          -1.0000, -1.0000, -1.0000, -1.0000],
#         [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#          -1.0000, -1.0000, -0.7804,  0.8588,  0.9922,  0.9922,  0.9922,  0.9922,
#           0.9922,  0.9922,  0.9451,  0.1529, -0.9216, -1.0000, -1.0000, -1.0000,
#          -1.0000, -1.0000, -1.0000, -1.0000],
#         [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#          -1.0000, -1.0000, -1.0000, -0.3882,  0.8510,  0.7490,  0.9922,  0.5137,
#           0.3020, -0.1216, -0.7412, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#          -1.0000, -1.0000, -1.0000, -1.0000],
#         [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#          -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#          -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#          -1.0000, -1.0000, -1.0000, -1.0000],
#         [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#          -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#          -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#          -1.0000, -1.0000, -1.0000, -1.0000],
#         [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#          -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#          -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#          -1.0000, -1.0000, -1.0000, -1.0000],
#         [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#          -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#          -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#          -1.0000, -1.0000, -1.0000, -1.0000],
#         [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#          -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#          -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#          -1.0000, -1.0000, -1.0000, -1.0000],
#         [-1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#          -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#          -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#          -1.0000, -1.0000, -1.0000, -1.0000]])
# torch.Size([28, 28])

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
for i in range(6):
  plt.subplot(2,3,i+1)
  plt.tight_layout()
  plt.imshow(example_data[i][0], cmap='gray', interpolation='none')
  plt.title("Ground Truth: {}".format(example_targets[i]))
  plt.xticks([])
  plt.yticks([])
fig

# %%
input_size = 1*28*28      
hidden1 = 64      
hidden2 = 64
hidden3 = 64
weight_bit_width = 1
act_bit_width = 1
num_classes = 10

# %%
import brevitas.nn as qnn
from brevitas.nn import QuantLinear, QuantReLU
import torch.nn as nn
from torch.nn import Module
from brevitas.quant.binary import SignedBinaryActPerTensorConst
from brevitas.quant.binary import SignedBinaryWeightPerTensorConst
from brevitas.inject.enum import QuantType

# Setting seeds for reproducibility
torch.manual_seed(0)

class TFC_W1A1(Module):
    def __init__(self):
        super(TFC_W1A1, self).__init__()
        
        self.input = qnn.QuantIdentity(
                         quant_type='binary',
                         scaling_impl_type='const',
                         bit_width=1,
                         min_val=-1.0,
                         max_val=1.0
                     )
        
        self.fc1   = qnn.QuantLinear(
                         input_size, 
                         hidden1, 
                         weight_bit_width=weight_bit_width,
                         weight_quant_type=QuantType.BINARY,
                         bias=False
                     )
        
        self.bn1   = nn.BatchNorm1d(hidden1)
        self.relu1 = qnn.QuantReLU(
                         bit_width=act_bit_width
                     )
        
        self.fc2   = qnn.QuantLinear(
                         hidden1, 
                         hidden2, 
                         weight_bit_width=weight_bit_width,
                         weight_quant_type=QuantType.BINARY,
                         bias=False
                     )
        self.bn2   = nn.BatchNorm1d(hidden2)
        self.relu2 = qnn.QuantReLU(
                         bit_width=act_bit_width, 
                         return_quant_tensor=True
                     )
        
        
        self.fc3   = qnn.QuantLinear(
                         hidden2, 
                         hidden3, 
                         weight_bit_width=weight_bit_width,
                         weight_quant_type=QuantType.BINARY,
                         bias=False
                     )
        self.bn3   = nn.BatchNorm1d(hidden3)
        self.relu3 = qnn.QuantReLU(
                         bit_width=act_bit_width, 
                         return_quant_tensor=True
                     )
        
        
        self.out   = qnn.QuantLinear(
                         hidden3, 
                         num_classes, 
                         weight_bit_width=weight_bit_width,
                         weight_quant_type=QuantType.BINARY,
                         bias=False
                     )

    def forward(self, x):
        out = x.reshape(x.shape[0], -1)
        out = self.input(out)
        out = self.relu1(self.bn1(self.fc1(out)))
        out = self.relu2(self.bn2(self.fc2(out)))
        out = self.relu3(self.bn3(self.fc3(out)))
        out = self.out(out)
        return out
   
model = TFC_W1A1()

#class TFC_W1A1(Module):
#    def __init__(self):
#        super(TFC_W1A1, self).__init__()
#        
#        self.input = qnn.QuantIdentity(
#                         quant_type=SignedBinaryActPerTensorConst, 
#                         return_quant_tensor=True
#                     )
#        
#        self.fc1   = qnn.QuantLinear(
#                         input_size, 
#                         hidden1, 
#                         input_quant=None,
#                         bias_quant=None,
#                         weight_quant=SignedBinaryWeightPerTensorConst, 
#                         output_quant=None,
#                         bias=True
#                     )
#        
#        self.bn1   = nn.BatchNorm1d(hidden1)
#        self.dp1   = nn.Dropout(0.5)
#        self.relu1 = qnn.QuantReLU(
#                         input_quant=None,
#                         act_quant=SignedBinaryActPerTensorConst, 
#                         return_quant_tensor=True
#                     )
#        
#        self.fc2   = qnn.QuantLinear(
#                         hidden1, 
#                         hidden2, 
#                         input_quant=None,
#                         bias_quant=None,
#                         weight_quant=SignedBinaryWeightPerTensorConst, 
#                         output_quant=None,
#                         bias=True
#                     )
#        self.bn2   = nn.BatchNorm1d(hidden2)
#        self.dp2   = nn.Dropout(0.5)
#        self.relu2 = qnn.QuantReLU(
#                         input_quant=None,
#                         act_quant=SignedBinaryActPerTensorConst, 
#                         return_quant_tensor=True
#                     )
#        
#        
#        self.fc3   = qnn.QuantLinear(
#                         hidden2, 
#                         hidden3, 
#                         input_quant=None,
#                         bias_quant=None,
#                         weight_quant=SignedBinaryWeightPerTensorConst, 
#                         output_quant=None,
#                         bias=True
#                     )
#        self.bn3   = nn.BatchNorm1d(hidden3)
#        self.dp3   = nn.Dropout(0.5)
#        self.relu3 = qnn.QuantReLU(
#                         input_quant=None,
#                         act_quant=SignedBinaryActPerTensorConst, 
#                         return_quant_tensor=True
#                     )
#        
#        
#        self.out   = qnn.QuantLinear(
#                         hidden3, 
#                         num_classes, 
#                         input_quant=None,
#                         bias_quant=None,
#                         weight_quant=SignedBinaryWeightPerTensorConst, 
#                         output_quant=None,
#                         bias=True
#                     )
#
#    def forward(self, x):
#        out = x.reshape(x.shape[0], -1)
#        out = self.input(out)
#        out = self.relu1(self.dp1(self.bn1(self.fc1(out))))
#        out = self.relu2(self.dp2(self.bn2(self.fc2(out))))
#        out = self.relu3(self.dp3(self.bn3(self.fc3(out))))
#        out = self.out(out)
#        return out
#   
#model = TFC_W1A1()

#model = nn.Sequential(
#      nn.Flatten(),
#      QuantLinear(input_size, hidden1, bias=True, weight_bit_width=weight_bit_width),
#      nn.BatchNorm1d(hidden1),
#      nn.Dropout(0.5),
#      QuantReLU(bit_width=act_bit_width),
#      QuantLinear(hidden1, hidden2, bias=True, weight_bit_width=weight_bit_width),
#      nn.BatchNorm1d(hidden2),
#      nn.Dropout(0.5),
#      QuantReLU(bit_width=act_bit_width),
#      QuantLinear(hidden2, hidden3, bias=True, weight_bit_width=weight_bit_width),
#      nn.BatchNorm1d(hidden3),
#      nn.Dropout(0.5),
#      QuantReLU(bit_width=act_bit_width),
#      QuantLinear(hidden3, num_classes, bias=True, weight_bit_width=weight_bit_width)
#)

#class LowPrecisionMLP(Module):
#    def __init__(self):
#        super(LowPrecisionMLP, self).__init__()
#        
#        self.fc1   = qnn.QuantLinear(input_size, hidden1, bias=True, weight_bit_width=weight_bit_width)
#        self.bn1   = nn.BatchNorm1d(hidden1)
#        self.dp1   = nn.Dropout(0.5)
#        self.relu1 = qnn.QuantReLU(bit_width=act_bit_width)
#        
#        self.fc2   = qnn.QuantLinear(hidden1, hidden2, bias=True, weight_bit_width=weight_bit_width)
#        self.bn2   = nn.BatchNorm1d(hidden2)
#        self.dp2   = nn.Dropout(0.5)
#        self.relu2 = qnn.QuantReLU(bit_width=act_bit_width)
#        
#        self.fc3   = qnn.QuantLinear(hidden2, hidden3, bias=True, weight_bit_width=weight_bit_width)
#        self.bn3   = nn.BatchNorm1d(hidden3)
#        self.dp3   = nn.Dropout(0.5)
#        self.relu3 = qnn.QuantReLU(bit_width=act_bit_width)
#        
#        self.out   = qnn.QuantLinear(hidden3, num_classes, bias=True, weight_bit_width=weight_bit_width)
#
#    def forward(self, x):
#        out = x.reshape(x.shape[0], -1)
#        out = self.relu1(self.dp1(self.bn1(self.fc1(out))))
#        out = self.relu2(self.dp2(self.bn2(self.fc2(out))))
#        out = self.relu3(self.dp3(self.bn3(self.fc3(out))))
#        out = self.out(out)
#        return out
    
#model = LowPrecisionMLP()

# %%
def train(model, train_loader, optimizer, criterion):
    losses = []
    # ensure model is in training mode
    model.train()    
    
    for i, data in enumerate(train_loader, 0):        
        inputs, target = data
        inputs, target = Variable(inputs), Variable(target)
        
        outputs = model(inputs)
        _,pred = torch.max(outputs.data,1)
        
        optimizer.zero_grad()
        loss = criterion(outputs,target)
 
        loss.backward()
        optimizer.step()
        
        # keep track of loss value
        losses.append(loss.data.numpy()) 
           
    return losses

# %%
import torch
from sklearn.metrics import accuracy_score

def test(model, test_loader):    
    # ensure model is in eval mode
    model.eval() 
    y_true = []
    y_pred = []
   
    with torch.no_grad():
        for data in test_loader:
            inputs, target = data
            inputs, target = Variable(inputs),Variable(target)
            output = model(inputs)
            #output = torch.sigmoid(output_orig)  
            _,pred = torch.max(output,1)
            # compare against a threshold of 0.5 to generate 0/1
            y_true.extend(target.tolist()) 
            y_pred.extend(pred.reshape(-1).tolist())
        
    return accuracy_score(y_true, y_pred)

# %%
num_epochs = 10
learn_rate = 0.001 

def display_loss_plot(losses, title="Training loss", xlabel="Iterations", ylabel="Loss"):
    x_axis = [i for i in range(len(losses))]
    plt.plot(x_axis,losses)
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.show()

# %%
# loss criterion and optimizer
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learn_rate, betas=(0.9, 0.999))

# %%
import numpy as np
from sklearn.metrics import accuracy_score
from tqdm import tqdm, trange

# Setting seeds for reproducibility
torch.manual_seed(0)
np.random.seed(0)

running_loss = []
running_test_acc = []
t = trange(num_epochs, desc="Training loss", leave=True)

for epoch in t:
        loss_epoch = train(model, data_loader_train, optimizer, criterion)
        test_acc = test(model, data_loader_test)
        t.set_description("Training loss = %f test accuracy = %f" % (np.mean(loss_epoch), test_acc))
        t.refresh() # to show immediately the update           
        running_loss.append(loss_epoch)
        running_test_acc.append(test_acc)
# Out:
# Training loss = 0.263665 test accuracy = 0.932100: 100%|█| 10/10 [03:06<00:00, 1

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

loss_per_epoch = [np.mean(loss_per_epoch) for loss_per_epoch in running_loss]
display_loss_plot(loss_per_epoch)

# %%
acc_per_epoch = [np.mean(acc_per_epoch) for acc_per_epoch in running_test_acc]
display_loss_plot(acc_per_epoch, title="Test accuracy", ylabel="Accuracy [%]")

# %%
test(model, data_loader_test)
# Out:
# 0.9321

# %%
torch.save(model.state_dict(), "tfc_w1a1.pth")

# %%
from brevitas.export import FINNManager

FINNManager.export(model, input_shape=(1, 28, 28), export_path='finn_tfc_w1a1.onnx')
# Out:
# [W shape_type_inference.cpp:1920] Warning: The shape inference of finn.custom_op.general::MultiThreshold type is missing, so it may result in wrong shape inference for the exported graph. Please consider adding it in symbolic function. (function UpdateReliable)
# ================ Diagnostic Run torch.onnx.export version 2.0.0 ================
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 1 WARNING 0 ERROR ========================
# 1 WARNING were not printed due to the log level.
# ir_version: 7
# producer_name: "pytorch"
# producer_version: "2.0.0"
# graph {
#   node {
#     input: "onnx::Reshape_0"
#     input: "/Constant_output_0"
#     output: "/Reshape_output_0"
#     name: "/Reshape"
#     op_type: "Reshape"
#     attribute {
#       name: "allowzero"
#       i: 0
#       type: INT
#     }
#   }
#   node {
#     input: "/Reshape_output_0"
#     input: "/input/export_handler/Constant_output_0"
#     output: "/input/export_handler/MultiThreshold_output_0"
#     name: "/input/export_handler/MultiThreshold"
#     op_type: "MultiThreshold"
#     attribute {
#       name: "out_bias"
#       f: -1.0
#       type: FLOAT
#     }
#     attribute {
#       name: "out_dtype"
#       s: "BIPOLAR"
#       type: STRING
#     }
#     attribute {
#       name: "out_scale"
#       f: 2.0
#       type: FLOAT
#     }
#     domain: "finn.custom_op.general"
#   }
#   node {
#     input: "/input/export_handler/MultiThreshold_output_0"
#     input: "/fc1/export_handler/Constant_output_0"
#     output: "/fc1/export_handler/MatMul_output_0"
#     name: "/fc1/export_handler/MatMul"
#     op_type: "MatMul"
#     domain: ""
#   }
#   node {
#     input: "/fc1/export_handler/MatMul_output_0"
#     input: "/fc1/export_handler/Constant_1_output_0"
#     output: "/fc1/export_handler/Mul_output_0"
#     name: "/fc1/export_handler/Mul"
#     op_type: "Mul"
#   }
#   node {
#     input: "/fc1/export_handler/Mul_output_0"
#     input: "bn1.weight"
#     input: "bn1.bias"
#     input: "bn1.running_mean"
#     input: "bn1.running_var"
#     output: "/bn1/BatchNormalization_output_0"
#     name: "/bn1/BatchNormalization"
#     op_type: "BatchNormalization"
#     attribute {
#       name: "epsilon"
#       f: 9.999999747378752e-06
#       type: FLOAT
#     }
#     attribute {
#       name: "momentum"
#       f: 0.8999999761581421
#       type: FLOAT
#     }
#     attribute {
#       name: "training_mode"
#       i: 0
#       type: INT
#     }
#   }
#   node {
#     input: "/bn1/BatchNormalization_output_0"
#     input: "/relu1/export_handler/Constant_output_0"
#     output: "/relu1/export_handler/MultiThreshold_output_0"
#     name: "/relu1/export_handler/MultiThreshold"
#     op_type: "MultiThreshold"
#     attribute {
#       name: "out_dtype"
#       s: "BINARY"
#       type: STRING
#     }
#     domain: "finn.custom_op.general"
#   }
#   node {
#     input: "/relu1/export_handler/MultiThreshold_output_0"
#     input: "/relu1/export_handler/Constant_1_output_0"
#     output: "/relu1/export_handler/Mul_output_0"
#     name: "/relu1/export_handler/Mul"
#     op_type: "Mul"
#   }
#   node {
#     input: "/relu1/export_handler/Mul_output_0"
#     input: "/fc2/export_handler/Constant_output_0"
#     output: "/fc2/export_handler/MatMul_output_0"
#     name: "/fc2/export_handler/MatMul"
#     op_type: "MatMul"
#     domain: ""
#   }
#   node {
#     input: "/fc2/export_handler/MatMul_output_0"
#     input: "/fc2/export_handler/Constant_1_output_0"
#     output: "/fc2/export_handler/Mul_output_0"
#     name: "/fc2/export_handler/Mul"
#     op_type: "Mul"
#   }
#   node {
#     input: "/fc2/export_handler/Mul_output_0"
#     input: "bn2.weight"
#     input: "bn2.bias"
#     input: "bn2.running_mean"
#     input: "bn2.running_var"
#     output: "/bn2/BatchNormalization_output_0"
#     name: "/bn2/BatchNormalization"
#     op_type: "BatchNormalization"
#     attribute {
#       name: "epsilon"
#       f: 9.999999747378752e-06
#       type: FLOAT
#     }
#     attribute {
#       name: "momentum"
#       f: 0.8999999761581421
#       type: FLOAT
#     }
#     attribute {
#       name: "training_mode"
#       i: 0
#       type: INT
#     }
#   }
#   node {
#     input: "/bn2/BatchNormalization_output_0"
#     input: "/relu2/export_handler/Constant_output_0"
#     output: "/relu2/export_handler/MultiThreshold_output_0"
#     name: "/relu2/export_handler/MultiThreshold"
#     op_type: "MultiThreshold"
#     attribute {
#       name: "out_dtype"
#       s: "BINARY"
#       type: STRING
#     }
#     domain: "finn.custom_op.general"
#   }
#   node {
#     input: "/relu2/export_handler/MultiThreshold_output_0"
#     input: "/relu2/export_handler/Constant_1_output_0"
#     output: "/relu2/export_handler/Mul_output_0"
#     name: "/relu2/export_handler/Mul"
#     op_type: "Mul"
#   }
#   node {
#     input: "/relu2/export_handler/Mul_output_0"
#     input: "/fc3/export_handler/Constant_output_0"
#     output: "/fc3/export_handler/MatMul_output_0"
#     name: "/fc3/export_handler/MatMul"
#     op_type: "MatMul"
#     domain: ""
#   }
#   node {
#     input: "/fc3/export_handler/MatMul_output_0"
#     input: "/fc3/export_handler/Constant_1_output_0"
#     output: "/fc3/export_handler/Mul_output_0"
#     name: "/fc3/export_handler/Mul"
#     op_type: "Mul"
#   }
#   node {
#     input: "/fc3/export_handler/Mul_output_0"
#     input: "bn3.weight"
#     input: "bn3.bias"
#     input: "bn3.running_mean"
#     input: "bn3.running_var"
#     output: "/bn3/BatchNormalization_output_0"
#     name: "/bn3/BatchNormalization"
#     op_type: "BatchNormalization"
#     attribute {
#       name: "epsilon"
#       f: 9.999999747378752e-06
#       type: FLOAT
#     }
#     attribute {
#       name: "momentum"
#       f: 0.8999999761581421
#       type: FLOAT
#     }
#     attribute {
#       name: "training_mode"
#       i: 0
#       type: INT
#     }
#   }
#   node {
#     input: "/bn3/BatchNormalization_output_0"
#     input: "/relu3/export_handler/Constant_output_0"
#     output: "/relu3/export_handler/MultiThreshold_output_0"
#     name: "/relu3/export_handler/MultiThreshold"
#     op_type: "MultiThreshold"
#     attribute {
#       name: "out_dtype"
#       s: "BINARY"
#       type: STRING
#     }
#     domain: "finn.custom_op.general"
#   }
#   node {
#     input: "/relu3/export_handler/MultiThreshold_output_0"
#     input: "/relu3/export_handler/Constant_1_output_0"
#     output: "/relu3/export_handler/Mul_output_0"
#     name: "/relu3/export_handler/Mul"
#     op_type: "Mul"
#   }
#   node {
#     input: "/relu3/export_handler/Mul_output_0"
#     input: "/out/export_handler/Constant_output_0"
#     output: "/out/export_handler/MatMul_output_0"
#     name: "/out/export_handler/MatMul"
#     op_type: "MatMul"
#     domain: ""
#   }
#   node {
#     input: "/out/export_handler/MatMul_output_0"
#     input: "/out/export_handler/Constant_1_output_0"
#     output: "63"
#     name: "/out/export_handler/Mul"
#     op_type: "Mul"
#   }
#   name: "torch_jit"
#   initializer {
#     dims: 64
#   }
#   initializer {
#     dims: 64
#     data_type: 1
#     name: "bn3.running_mean"
#     raw_data: "\252\354+\300F!!@8\303T@\254\252\302\300\222\304\340?\270\322\031\301\001\257U?\216\370\324\300\034\373\206\277d\2220\300h\261\234\277\326\312\214\300\241.!\300\026K\347\300C\361L\300\212\357\240>\332\354J@1N\260>\2458\237\300Q\221\253@z \222@\343\255\032@\036\364w\277\3660\345\300\321\360\023?MZ\305\300>\025\256\300Ph\031\300\304\217\314<n\304k\300G\364F@\001D\324=jI\010\277\273\244\202\300B\2129\301\203c9\300lqj@nn\266\300e\350p\300\364\332+>\313\276\204\300`\363\257\300\016,\373\300ZA\236\300\006\251\200\300\013\332\362\300u\201\355\277\277F\'\301L\r\216\300UD.@L\305\367\276;+\036\300\212\361\251\277\347$%=\250\322*@\247\363\314?o\200c@\366I\223\300:\267\016\301V\t\240\300RA\204\277p\214\027\301\031D[\300\371\206*?"
#   }
#   initializer {
#     dims: 64
#     data_type: 1
#     name: "bn3.running_var"
#     raw_data: "\213\353@B)J\231BBM\221B\324\204\323Bq\016\312B\004_\207B%t\233B\030S\244BE\302~Bi\365\263B\312\003\254B\354b\272B&\014\236B\314fTBE\r\220B\333^\326B\225\022{B\334\204\350Bi\275\271B\357\376\243B}A\201BicvB\260;\217B\223Q\325B\233W\243B\265\233\244Bl\265JB,\336\231B9\303\267B\3055\203B6\210XB\031\233\247B\204\351\301B\t\023\303B\257\233\205B\361\0218B\342\326\201B_\240\313B\023\252\253B\364\234\343B+\352\206B\212\266\220B\324\322\211B\212\037\207Bf\257vB)H\213B\355\035\254B\300\010\260B\013@\273BuZ\245B&V\231B\033\354\315BB\355|B\'\270<B\001\321\215B\353 \332B\312\262SBJ\231\235B\332\206uB;\004\301B\337\274\212B\203khBq\"\204B\030\310sB"
#   }
#   initializer {
#     dims: 2
#     data_type: 7
#     name: "/Constant_output_0"
#     raw_data: "\001\000\000\000\000\000\000\000\377\377\377\377\377\377\377\377"
#   }
#   initializer {
#     dims: 1
#     dims: 1
#     data_type: 1
#     name: "/input/export_handler/Constant_output_0"
#     raw_data: "\000\000\000\000"
#   }
#   initializer {
#     dims: 784
#     dims: 64
#     data_type: 1
#     name: "/fc1/export_handler/Constant_output_0"
#     raw_data: "\000\000\200?\000\000\200\277\000\000\200\277\000\000\200?\000\000\200?\000\000\200\277\000\000\200\277\000\000\200?\000\000\200?\000\000\200\277\000\000\200\277\000\000\200?\000\000\200?\000\000\200?\000\000\200\277\000\000\200\277\000\000\200?\000\000\200?\000\000\200?\000\000\200?\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200?\000\000\200?\000\000\200?\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200?\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200?\000\000\200?\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200?\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200?\000\000\200?\000\000\200?\000\000\200\277\000\000\200?\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200?\000\000\200?\000\000\200?\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200?\000\000\200?\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200?\000\000\200\277\000\000\200?\000\000\200?\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200?\000\000\200?\000\000\200\277\000\000\200\277\000\000\200?\000\000\200?\000\000\200?\000\000\200\277\000\000\200?\000\000\200?\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200?\000\000\200?\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200?\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200?\000\000\200?\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200?\000\000\200\277\000\000\200?\000\000\200?\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200?\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200 ...
#   }
#   initializer {
#     data_type: 1
#     name: "/fc1/export_handler/Constant_1_output_0"
#     raw_data: "Z=\320?"
#   }
#   initializer {
#     dims: 64
#     dims: 1
#     data_type: 1
#     name: "/relu1/export_handler/Constant_output_0"
#     raw_data: "*a\007?*a\007?*a\007?*a\007?*a\007?*a\007?*a\007?*a\007?*a\007?*a\007?*a\007?*a\007?*a\007?*a\007?*a\007?*a\007?*a\007?*a\007?*a\007?*a\007?*a\007?*a\007?*a\007?*a\007?*a\007?*a\007?*a\007?*a\007?*a\007?*a\007?*a\007?*a\007?*a\007?*a\007?*a\007?*a\007?*a\007?*a\007?*a\007?*a\007?*a\007?*a\007?*a\007?*a\007?*a\007?*a\007?*a\007?*a\007?*a\007?*a\007?*a\007?*a\007?*a\007?*a\007?*a\007?*a\007?*a\007?*a\007?*a\007?*a\007?*a\007?*a\007?*a\007?*a\007?"
#   }
#   initializer {
#     data_type: 1
#     name: "/relu1/export_handler/Constant_1_output_0"
#     raw_data: "*a\207?"
#   }
#   initializer {
#     dims: 64
#     dims: 64
#     data_type: 1
#     name: "/fc2/export_handler/Constant_output_0"
#     raw_data: "\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200?\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200?\000\000\200\277\000\000\200?\000\000\200?\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200?\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200?\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200?\000\000\200?\000\000\200?\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200?\000\000\200?\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200?\000\000\200?\000\000\200?\000\000\200\277\000\000\200?\000\000\200?\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200?\000\000\200?\000\000\200\277\000\000\200?\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200?\000\000\200?\000\000\200?\000\000\200?\000\000\200\277\000\000\200?\000\000\200?\000\000\200?\000\000\200?\000\000\200\277\000\000\200?\000\000\200?\000\000\200?\000\000\200?\000\000\200?\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200?\000\000\200?\000\000\200?\000\000\200\277\000\000\200?\000\000\200?\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200?\000\000\200?\000\000\200?\000\000\200\277\000\000\200?\000\000\200?\000\000\200?\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200?\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200?\000\000\200?\000\000\200?\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200?\000\000\200\277\000\000\200?\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200?\000\000\200\277\000\000\200?\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200?\000\000\200?\000\000\200?\000\000\200\277\000\000\200?\000\000\200?\000\000\200?\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200?\000\000\200?\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200?\000\000\200\277\000\0 ...
#   }
#   initializer {
#     data_type: 1
#     name: "/fc2/export_handler/Constant_1_output_0"
#     raw_data: "\377`\323?"
#   }
#   initializer {
#     dims: 64
#     dims: 1
#     data_type: 1
#     name: "/relu2/export_handler/Constant_output_0"
#     raw_data: "\212\010>?\212\010>?\212\010>?\212\010>?\212\010>?\212\010>?\212\010>?\212\010>?\212\010>?\212\010>?\212\010>?\212\010>?\212\010>?\212\010>?\212\010>?\212\010>?\212\010>?\212\010>?\212\010>?\212\010>?\212\010>?\212\010>?\212\010>?\212\010>?\212\010>?\212\010>?\212\010>?\212\010>?\212\010>?\212\010>?\212\010>?\212\010>?\212\010>?\212\010>?\212\010>?\212\010>?\212\010>?\212\010>?\212\010>?\212\010>?\212\010>?\212\010>?\212\010>?\212\010>?\212\010>?\212\010>?\212\010>?\212\010>?\212\010>?\212\010>?\212\010>?\212\010>?\212\010>?\212\010>?\212\010>?\212\010>?\212\010>?\212\010>?\212\010>?\212\010>?\212\010>?\212\010>?\212\010>?\212\010>?"
#   }
#   initializer {
#     data_type: 1
#     name: "/relu2/export_handler/Constant_1_output_0"
#     raw_data: "\212\010\276?"
#   }
#   initializer {
#     dims: 64
#     dims: 64
#     data_type: 1
#     name: "/fc3/export_handler/Constant_output_0"
#     raw_data: "\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200?\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200?\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200?\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200?\000\000\200?\000\000\200\277\000\000\200?\000\000\200?\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200?\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200?\000\000\200\277\000\000\200?\000\000\200?\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200?\000\000\200?\000\000\200\277\000\000\200?\000\000\200?\000\000\200?\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200?\000\000\200?\000\000\200\277\000\000\200?\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200?\000\000\200?\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200?\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200?\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200?\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200?\000\000\200?\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200?\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200?\000\000\200?\000\000\200\277\000\000\200?\000\000\200?\000\000\200\277\000\000\200\277\000\000\200?\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200?\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200?\000\0 ...
#   }
#   initializer {
#     data_type: 1
#     name: "/fc3/export_handler/Constant_1_output_0"
#     raw_data: "\031h^?"
#   }
#   initializer {
#     dims: 64
#     dims: 1
#     data_type: 1
#     name: "/relu3/export_handler/Constant_output_0"
#     raw_data: "\242\324>?\242\324>?\242\324>?\242\324>?\242\324>?\242\324>?\242\324>?\242\324>?\242\324>?\242\324>?\242\324>?\242\324>?\242\324>?\242\324>?\242\324>?\242\324>?\242\324>?\242\324>?\242\324>?\242\324>?\242\324>?\242\324>?\242\324>?\242\324>?\242\324>?\242\324>?\242\324>?\242\324>?\242\324>?\242\324>?\242\324>?\242\324>?\242\324>?\242\324>?\242\324>?\242\324>?\242\324>?\242\324>?\242\324>?\242\324>?\242\324>?\242\324>?\242\324>?\242\324>?\242\324>?\242\324>?\242\324>?\242\324>?\242\324>?\242\324>?\242\324>?\242\324>?\242\324>?\242\324>?\242\324>?\242\324>?\242\324>?\242\324>?\242\324>?\242\324>?\242\324>?\242\324>?\242\324>?\242\324>?"
#   }
#   initializer {
#     data_type: 1
#     name: "/relu3/export_handler/Constant_1_output_0"
#     raw_data: "\242\324\276?"
#   }
#   initializer {
#     dims: 64
#     dims: 10
#     data_type: 1
#     name: "/out/export_handler/Constant_output_0"
#     raw_data: "\000\000\200?\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200?\000\000\200?\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200?\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200?\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200?\000\000\200?\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200?\000\000\200?\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200?\000\000\200?\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200?\000\000\200\277\000\000\200\277\000\000\200?\000\0 ...
#   }
#   initializer {
#     data_type: 1
#     name: "/out/export_handler/Constant_1_output_0"
#     raw_data: "\227*Z>"
#   }
#   input {
#     name: "onnx::Reshape_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 28
#           }
#           dim {
#             dim_value: 28
#           }
#         }
#       }
#     }
#   }
#   input {
#     name: "bn1.weight"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 64
#           }
#         }
#       }
#     }
#   }
#   input {
#     name: "bn1.bias"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 64
#           }
#         }
#       }
#     }
#   }
#   input {
#     name: "bn1.running_mean"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 64
#           }
#         }
#       }
#     }
#   }
#   input {
#     name: "bn1.running_var"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 64
#           }
#         }
#       }
#     }
#   }
#   input {
#     name: "bn2.weight"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 64
#           }
#         }
#       }
#     }
#   }
#   input {
#     name: "bn2.bias"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 64
#           }
#         }
#       }
#     }
#   }
#   input {
#     name: "bn2.running_mean"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 64
#           }
#         }
#       }
#     }
#   }
#   input {
#     name: "bn2.running_var"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 64
#           }
#         }
#       }
#     }
#   }
#   input {
#     name: "bn3.weight"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 64
#           }
#         }
#       }
#     }
#   }
#   input {
#     name: "bn3.bias"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 64
#           }
#         }
#       }
#     }
#   }
#   input {
#     name: "bn3.running_mean"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 64
#           }
#         }
#       }
#     }
#   }
#   input {
#     name: "bn3.running_var"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 64
#           }
#         }
#       }
#     }
#   }
#   output {
#     name: "63"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_param: "Mul63_dim_0"
#           }
#           dim {
#             dim_param: "Mul63_dim_1"
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/input/export_handler/MultiThreshold_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_param: "MultiThreshold/input/export_handler/MultiThreshold_output_0_dim_0"
#           }
#           dim {
#             dim_param: "MultiThreshold/input/export_handler/MultiThreshold_output_0_dim_1"
#           }
#         }
#       }
#     }
#   }
#   quantization_annotation {
#     tensor_name: "/fc1/export_handler/Constant_output_0"
#     quant_parameter_tensor_names {
#       key: "finn_datatype"
#       value: "BIPOLAR"
#     }
#   }
#   quantization_annotation {
#     tensor_name: "/fc2/export_handler/Constant_output_0"
#     quant_parameter_tensor_names {
#       key: "finn_datatype"
#       value: "BIPOLAR"
#     }
#   }
#   quantization_annotation {
#     tensor_name: "/fc3/export_handler/Constant_output_0"
#     quant_parameter_tensor_names {
#       key: "finn_datatype"
#       value: "BIPOLAR"
#     }
#   }
#   quantization_annotation {
#     tensor_name: "/out/export_handler/Constant_output_0"
#     quant_parameter_tensor_names {
#       key: "finn_datatype"
#       value: "BIPOLAR"
#     }
#   }
# }
# opset_import {
#   domain: ""
#   version: 14
# }
# opset_import {
#   domain: "finn.custom_op.general"
#   version: 1
# }
