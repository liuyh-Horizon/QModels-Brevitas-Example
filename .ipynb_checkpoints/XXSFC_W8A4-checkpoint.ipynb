# %%
import torch
from torch import nn
from torch.nn import Module
import torch.nn.functional as F

# %%
import torchvision
from torchvision import datasets
from torchvision import transforms
from torch.autograd import Variable

# %%
import brevitas.nn as qnn
from brevitas.quant import Int8Bias as BiasQuant
from brevitas.export import FINNManager
from brevitas.export import StdQOpONNXManager

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
import time

# %%
start_time = time.time()

# %%
n_epochs = 3
batch_size_train = 64
batch_size_test = 1000
learning_rate = 0.01
momentum = 0.5
log_interval = 10

random_seed = 1
torch.backends.cudnn.enabled = False
torch.manual_seed(random_seed)

# %%
data_train = torchvision.datasets.MNIST('./data/', 
                                        train=True, download=True,
                                        transform=torchvision.transforms.Compose
                                        ([
                                            torchvision.transforms.ToTensor(),
                                            torchvision.transforms.Normalize((0.1307,), (0.3081,))
                                        ]))
data_test = torchvision.datasets.MNIST('./data/', 
                                       train=False, download=True,
                                       transform=torchvision.transforms.Compose
                                       ([
                                            torchvision.transforms.ToTensor(),
                                            torchvision.transforms.Normalize((0.1307,), (0.3081,))
                                       ]))

# %%
data_loader_train = torch.utils.data.DataLoader(dataset=data_train,
                                                batch_size=batch_size_train, 
                                                shuffle=True)

# %%
data_loader_test = torch.utils.data.DataLoader(dataset=data_test,
                                               batch_size=batch_size_test, 
                                               shuffle=True)

# %%
examples = enumerate(data_loader_test)
batch_idx, (example_data, example_targets) = next(examples)
example_data.shape
# Out:
# torch.Size([1000, 1, 28, 28])

# %%
fig = plt.figure()
for i in range(6):
  plt.subplot(2,3,i+1)
  plt.tight_layout()
  plt.imshow(example_data[i][0], cmap='gray', interpolation='none')
  plt.title("Ground Truth: {}".format(example_targets[i]))
  plt.xticks([])
  plt.yticks([])
fig

# %%
class LowPrecisionMLP(Module):
    def __init__(self):
        super(LowPrecisionMLP, self).__init__()
        self.quant_inp = qnn.QuantIdentity(
            bit_width=4, return_quant_tensor=True)
        self.fc1   = qnn.QuantLinear(
            1*28*28, 32, bias=True, weight_bit_width=8, bias_quant=BiasQuant, return_quant_tensor=True)
        self.relu1 = qnn.QuantReLU(
            bit_width=4, return_quant_tensor=True)
        self.fc2   = qnn.QuantLinear(
            32, 32, bias=True, weight_bit_width=8, bias_quant=BiasQuant, return_quant_tensor=True)
        self.relu2 = qnn.QuantReLU(
            bit_width=4, return_quant_tensor=True)
        self.fc3   = qnn.QuantLinear(
            32, 32, bias=True, weight_bit_width=8, bias_quant=BiasQuant, return_quant_tensor=True)
        self.relu3 = qnn.QuantReLU(
            bit_width=4, return_quant_tensor=True)
        self.fc4   = qnn.QuantLinear(
            32, 10, bias=False, weight_bit_width=8)

    def forward(self, x):
        out = self.quant_inp(x)
        out = out.reshape(out.shape[0], -1)
        out = self.relu1(self.fc1(out))
        out = self.relu2(self.fc2(out))
        out = self.relu3(self.fc3(out))
        out = self.fc4(out)
        return out

# %%
low_precision_mlp = LowPrecisionMLP()

# %%
cost=torch.nn.CrossEntropyLoss()

# %%
optimizer = torch.optim.Adam(low_precision_mlp.parameters())

# %%
# 卷积神经网络模型进行模型训练和参数优化的代码
n_epochs = 5
 
for epoch in range(n_epochs):
    running_loss = 0.0
    running_correct = 0
    print("Epoch  {}/{}".format(epoch, n_epochs))
    print("-"*10)
    for data in data_loader_train:
        X_train , y_train = data
        # 有GPU加下面这行，没有不用加
        # X_train, y_train = X_train.cuda(), y_train.cuda()
        X_train , y_train = Variable(X_train),Variable(y_train)
        # print(y_train)
        outputs = low_precision_mlp(X_train)
        # print(outputs)
        _,pred = torch.max(outputs.data,1)
        optimizer.zero_grad()
        loss = cost(outputs,y_train)
 
        loss.backward()
        optimizer.step()
        # running_loss += loss.data[0]
        running_loss += loss.item()
        running_correct += torch.sum(pred == y_train.data)
        # print("ok")
        # print("**************%s"%running_corrrect)
 
    print("train ok ")
    testing_correct = 0
    for data in data_loader_test:
        X_test,y_test = data
        # 有GPU加下面这行，没有不用加
        # X_test, y_test = X_test.cuda(), y_test.cuda()
        X_test,y_test = Variable(X_test),Variable(y_test)
        outputs = low_precision_mlp(X_test)
        _, pred = torch.max(outputs,1)
        testing_correct += torch.sum(pred == y_test.data)
        # print(testing_correct)
 
    print( "Loss is :{:.4f},Train Accuracy is:{:.4f}%,Test Accuracy is:{:.4f}".format(
                 running_loss / len(data_train),100 * running_correct / len(data_train),
                 100 * testing_correct / len(data_test)))
# Out:
# Epoch  0/5
# ----------
# train ok
# Loss is :0.0064,Train Accuracy is:87.5450%,Test Accuracy is:92.9600
# Epoch  1/5
# ----------
# train ok
# Loss is :0.0030,Train Accuracy is:94.2733%,Test Accuracy is:94.7700
# Epoch  2/5
# ----------
# train ok
# Loss is :0.0024,Train Accuracy is:95.3467%,Test Accuracy is:94.5500
# Epoch  3/5
# ----------
# train ok
# Loss is :0.0020,Train Accuracy is:96.0483%,Test Accuracy is:95.4200
# Epoch  4/5
# ----------
# train ok
# Loss is :0.0017,Train Accuracy is:96.5500%,Test Accuracy is:95.5500

# %%
stop_time = time.time()
print("time is %s" %(stop_time-start_time))
# Out:
# time is 102.65259170532227

# %%
FINNManager.export(low_precision_mlp, input_shape=(1, 28, 28), export_path='finn_xxsfc_w8a4.onnx')
# Out:
# ================ Diagnostic Run torch.onnx.export version 2.0.0 ================
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================
# ir_version: 7
# producer_name: "pytorch"
# producer_version: "2.0.0"
# graph {
#   node {
#     input: "inp.1"
#     input: "/quant_inp/export_handler/Constant_output_0"
#     output: "/quant_inp/export_handler/MultiThreshold_output_0"
#     name: "/quant_inp/export_handler/MultiThreshold"
#     op_type: "MultiThreshold"
#     attribute {
#       name: "out_dtype"
#       s: "INT4"
#       type: STRING
#     }
#     domain: "finn.custom_op.general"
#   }
#   node {
#     input: "/quant_inp/export_handler/MultiThreshold_output_0"
#     input: "/quant_inp/export_handler/Constant_1_output_0"
#     output: "/quant_inp/export_handler/Add_output_0"
#     name: "/quant_inp/export_handler/Add"
#     op_type: "Add"
#     domain: ""
#   }
#   node {
#     input: "/quant_inp/export_handler/Add_output_0"
#     input: "/quant_inp/export_handler/Constant_2_output_0"
#     output: "/quant_inp/export_handler/Mul_output_0"
#     name: "/quant_inp/export_handler/Mul"
#     op_type: "Mul"
#   }
#   node {
#     input: "/quant_inp/export_handler/Mul_output_0"
#     output: "/Shape_output_0"
#     name: "/Shape"
#     op_type: "Shape"
#   }
#   node {
#     input: "/Shape_output_0"
#     input: "/Constant_output_0"
#     output: "/Gather_output_0"
#     name: "/Gather"
#     op_type: "Gather"
#     attribute {
#       name: "axis"
#       i: 0
#       type: INT
#     }
#   }
#   node {
#     input: "/Gather_output_0"
#     input: "onnx::Unsqueeze_22"
#     output: "/Unsqueeze_output_0"
#     name: "/Unsqueeze"
#     op_type: "Unsqueeze"
#   }
#   node {
#     input: "/Unsqueeze_output_0"
#     input: "/Constant_1_output_0"
#     output: "/Concat_output_0"
#     name: "/Concat"
#     op_type: "Concat"
#     attribute {
#       name: "axis"
#       i: 0
#       type: INT
#     }
#   }
#   node {
#     input: "/quant_inp/export_handler/Mul_output_0"
#     input: "/Concat_output_0"
#     output: "/Reshape_output_0"
#     name: "/Reshape"
#     op_type: "Reshape"
#     attribute {
#       name: "allowzero"
#       i: 0
#       type: INT
#     }
#   }
#   node {
#     input: "/Reshape_output_0"
#     input: "/fc1/export_handler/Constant_output_0"
#     output: "/fc1/export_handler/MatMul_output_0"
#     name: "/fc1/export_handler/MatMul"
#     op_type: "MatMul"
#     domain: ""
#   }
#   node {
#     input: "/fc1/export_handler/MatMul_output_0"
#     input: "/fc1/export_handler/Constant_2_output_0"
#     output: "/fc1/export_handler/Mul_output_0"
#     name: "/fc1/export_handler/Mul"
#     op_type: "Mul"
#   }
#   node {
#     input: "/fc1/export_handler/Mul_output_0"
#     input: "/fc1/export_handler/Constant_3_output_0"
#     output: "/fc1/export_handler/Div_output_0"
#     name: "/fc1/export_handler/Div"
#     op_type: "Div"
#     domain: ""
#   }
#   node {
#     input: "/fc1/export_handler/Div_output_0"
#     input: "/fc1/export_handler/Constant_1_output_0"
#     output: "/fc1/export_handler/Add_output_0"
#     name: "/fc1/export_handler/Add"
#     op_type: "Add"
#     domain: ""
#   }
#   node {
#     input: "/fc1/export_handler/Add_output_0"
#     input: "/fc1/export_handler/Constant_4_output_0"
#     output: "/fc1/export_handler/Mul_1_output_0"
#     name: "/fc1/export_handler/Mul_1"
#     op_type: "Mul"
#   }
#   node {
#     input: "/fc1/export_handler/Mul_1_output_0"
#     input: "/relu1/export_handler/Constant_output_0"
#     output: "/relu1/export_handler/MultiThreshold_output_0"
#     name: "/relu1/export_handler/MultiThreshold"
#     op_type: "MultiThreshold"
#     attribute {
#       name: "out_dtype"
#       s: "UINT4"
#       type: STRING
#     }
#     domain: "finn.custom_op.general"
#   }
#   node {
#     input: "/relu1/export_handler/MultiThreshold_output_0"
#     input: "/relu1/export_handler/Constant_1_output_0"
#     output: "/relu1/export_handler/Mul_output_0"
#     name: "/relu1/export_handler/Mul"
#     op_type: "Mul"
#   }
#   node {
#     input: "/relu1/export_handler/Mul_output_0"
#     input: "/fc2/export_handler/Constant_output_0"
#     output: "/fc2/export_handler/MatMul_output_0"
#     name: "/fc2/export_handler/MatMul"
#     op_type: "MatMul"
#     domain: ""
#   }
#   node {
#     input: "/fc2/export_handler/MatMul_output_0"
#     input: "/fc2/export_handler/Constant_2_output_0"
#     output: "/fc2/export_handler/Mul_output_0"
#     name: "/fc2/export_handler/Mul"
#     op_type: "Mul"
#   }
#   node {
#     input: "/fc2/export_handler/Mul_output_0"
#     input: "/fc2/export_handler/Constant_3_output_0"
#     output: "/fc2/export_handler/Div_output_0"
#     name: "/fc2/export_handler/Div"
#     op_type: "Div"
#     domain: ""
#   }
#   node {
#     input: "/fc2/export_handler/Div_output_0"
#     input: "/fc2/export_handler/Constant_1_output_0"
#     output: "/fc2/export_handler/Add_output_0"
#     name: "/fc2/export_handler/Add"
#     op_type: "Add"
#     domain: ""
#   }
#   node {
#     input: "/fc2/export_handler/Add_output_0"
#     input: "/fc2/export_handler/Constant_4_output_0"
#     output: "/fc2/export_handler/Mul_1_output_0"
#     name: "/fc2/export_handler/Mul_1"
#     op_type: "Mul"
#   }
#   node {
#     input: "/fc2/export_handler/Mul_1_output_0"
#     input: "/relu2/export_handler/Constant_output_0"
#     output: "/relu2/export_handler/MultiThreshold_output_0"
#     name: "/relu2/export_handler/MultiThreshold"
#     op_type: "MultiThreshold"
#     attribute {
#       name: "out_dtype"
#       s: "UINT4"
#       type: STRING
#     }
#     domain: "finn.custom_op.general"
#   }
#   node {
#     input: "/relu2/export_handler/MultiThreshold_output_0"
#     input: "/relu2/export_handler/Constant_1_output_0"
#     output: "/relu2/export_handler/Mul_output_0"
#     name: "/relu2/export_handler/Mul"
#     op_type: "Mul"
#   }
#   node {
#     input: "/relu2/export_handler/Mul_output_0"
#     input: "/fc3/export_handler/Constant_output_0"
#     output: "/fc3/export_handler/MatMul_output_0"
#     name: "/fc3/export_handler/MatMul"
#     op_type: "MatMul"
#     domain: ""
#   }
#   node {
#     input: "/fc3/export_handler/MatMul_output_0"
#     input: "/fc3/export_handler/Constant_2_output_0"
#     output: "/fc3/export_handler/Mul_output_0"
#     name: "/fc3/export_handler/Mul"
#     op_type: "Mul"
#   }
#   node {
#     input: "/fc3/export_handler/Mul_output_0"
#     input: "/fc3/export_handler/Constant_3_output_0"
#     output: "/fc3/export_handler/Div_output_0"
#     name: "/fc3/export_handler/Div"
#     op_type: "Div"
#     domain: ""
#   }
#   node {
#     input: "/fc3/export_handler/Div_output_0"
#     input: "/fc3/export_handler/Constant_1_output_0"
#     output: "/fc3/export_handler/Add_output_0"
#     name: "/fc3/export_handler/Add"
#     op_type: "Add"
#     domain: ""
#   }
#   node {
#     input: "/fc3/export_handler/Add_output_0"
#     input: "/fc3/export_handler/Constant_4_output_0"
#     output: "/fc3/export_handler/Mul_1_output_0"
#     name: "/fc3/export_handler/Mul_1"
#     op_type: "Mul"
#   }
#   node {
#     input: "/fc3/export_handler/Mul_1_output_0"
#     input: "/relu3/export_handler/Constant_output_0"
#     output: "/relu3/export_handler/MultiThreshold_output_0"
#     name: "/relu3/export_handler/MultiThreshold"
#     op_type: "MultiThreshold"
#     attribute {
#       name: "out_dtype"
#       s: "UINT4"
#       type: STRING
#     }
#     domain: "finn.custom_op.general"
#   }
#   node {
#     input: "/relu3/export_handler/MultiThreshold_output_0"
#     input: "/relu3/export_handler/Constant_1_output_0"
#     output: "/relu3/export_handler/Mul_output_0"
#     name: "/relu3/export_handler/Mul"
#     op_type: "Mul"
#   }
#   node {
#     input: "/relu3/export_handler/Mul_output_0"
#     input: "/fc4/export_handler/Constant_output_0"
#     output: "/fc4/export_handler/MatMul_output_0"
#     name: "/fc4/export_handler/MatMul"
#     op_type: "MatMul"
#     domain: ""
#   }
#   node {
#     input: "/fc4/export_handler/MatMul_output_0"
#     input: "/fc4/export_handler/Constant_1_output_0"
#     output: "73"
#     name: "/fc4/export_handler/Mul"
#     op_type: "Mul"
#   }
#   name: "torch_jit"
#   initializer {
#     dims: 28
#     dims: 15
#     data_type: 1
#     name: "/quant_inp/export_handler/Constant_output_0"
#     raw_data: "\267j5\300Z:\035\300\376\t\005\300B\263\331\277\210R\251\277\234\343q\277,\"\021\277\340\202A\276\360\202A>0\"\021?\244\343q?\212R\251?B\263\331?\377\t\005@[:\035@\267j5\300Z:\035\300\376\t\005\300B\263\331\277\210R\251\277\234\343q\277,\"\021\277\340\202A\276\360\202A>0\"\021?\244\343q?\212R\251?B\263\331?\377\t\005@[:\035@\267j5\300Z:\035\300\376\t\005\300B\263\331\277\210R\251\277\234\343q\277,\"\021\277\340\202A\276\360\202A>0\"\021?\244\343q?\212R\251?B\263\331?\377\t\005@[:\035@\267j5\300Z:\035\300\376\t\005\300B\263\331\277\210R\251\277\234\343q\277,\"\021\277\340\202A\276\360\202A>0\"\021?\244\343q?\212R\251?B\263\331?\377\t\005@[:\035@\267j5\300Z:\035\300\376\t\005\300B\263\331\277\210R\251\277\234\343q\277,\"\021\277\340\202A\276\360\202A>0\"\021?\244\343q?\212R\251?B\263\331?\377\t\005@[:\035@\267j5\300Z:\035\300\376\t\005\300B\263\331\277\210R\251\277\234\343q\277,\"\021\277\340\202A\276\360\202A>0\"\021?\244\343q?\212R\251?B\263\331?\377\t\005@[:\035@\267j5\300Z:\035\300\376\t\005\300B\263\331\277\210R\251\277\234\343q\277,\"\021\277\340\202A\276\360\202A>0\"\021?\244\343q?\212R\251?B\263\331?\377\t\005@[:\035@\267j5\300Z:\035\300\376\t\005\300B\263\331\277\210R\251\277\234\343q\277,\"\021\277\340\202A\276\360\202A>0\"\021?\244\343q?\212R\251?B\263\331?\377\t\005@[:\035@\267j5\300Z:\035\300\376\t\005\300B\263\331\277\210R\251\277\234\343q\277,\"\021\277\340\202A\276\360\202A>0\"\021?\244\343q?\212R\251?B\263\331?\377\t\005@[:\035@\267j5\300Z:\035\300\376\t\005\300B\263\331\277\210R\251\277\234\343q\277,\"\021\277\340\202A\276\360\202A>0\"\021?\244\343q?\212R\251?B\263\331?\377\t\005@[:\035@\267j5\300Z:\035\300\376\t\005\300B\263\331\277\210R\251\277\234\343q\277,\"\021\277\340\202A\276\360\202A>0\"\021?\244\343q?\212R\251?B\263\331?\377\t\005@[:\035@\267j5\300Z:\035\300\376\t\005\300B\263\331\277\210R\251\277\234\343q\277,\"\021\277\340\202A\276\360\202A>0\"\021?\244\343q?\212R\251?B\263\331?\377\t\005@[:\035@\267j5\300Z:\035\300\376\t\005\300B\263\331\277\210R\251\277\234\343q\277,\"\021\277\340\202A\276\360\202A>0\"\021?\244\343q?\212R\251?B\263\331?\377\t\005@[:\035@\267j5\300Z:\035\300\376\t\005\300B\263\331\277\210R\251\277\234\343q\277,\"\021\277\340\202A\276\360\202A>0\"\021?\244\343q?\212R\251?B\263\331?\377\t\005@[:\035@\267j5\300Z:\035\300\376\t\005\300B\263\331\277\210R\251\277\234\343q\277,\"\021\277\340\202A\276\360\202A>0\"\021?\244\343q?\212R\251?B\263\331?\377\t\005@[:\035@\267j5\300Z:\035\300\376\t\005\300B\263\331\277\210R\251\277\234\343q\277,\"\021\277\340\202A\276\360\202A>0\"\021?\244\343q?\212R\251?B\263\331?\377\t\005@[:\035@\267j5\300Z:\035\300\376\t\005\300B\263\331\277\210R\251\277\234\343q\277,\"\021\277\340\202A\276\360\202A>0\"\021?\244\343q?\212R\251?B\263\331?\377\t\005@[:\035@\267j5\300Z:\035\300\376\t\005\300B\263\331\277\210R\251\277\234\343q\277,\"\021\277\340\202A\276\360\202A>0\"\021?\244\343q?\212R\251?B\263\331?\377\t\005@[:\035@\267j5\300Z:\035\300\376\t\005\300B\263\331\277\210R\251\277\234\343q\277,\"\021\277\340\202A\276\360\202A>0\"\021?\244\343q?\212R\251?B\263\331?\377\t\005@[:\035@\267j5\300Z:\035\300\376\t\005\300B\263\331\277\210R\251\277\234\343q\277,\"\021\277\340\202A\276\360\202A>0\"\021?\244\343q?\212R\251?B\263\331?\377\t\005@[:\035@\267j5\300Z:\035\300\376\t\005\300B\263\331\277\210R\251\277\234\343q\277,\"\021\277\340\202A\276\360\202A>0\"\021?\244\343q?\212R\251?B\263\331?\377\t\005@[:\035@\267j5\300Z:\035\300\376\t\005\300B\263\331\277\210R\251\277\234\343q\277,\"\021\277\340\202A\276\360\202A>0\"\021?\244\343q?\212R\251?B\263\331?\377\t\005@[:\035@\267j5\300Z:\035\300\376\t\005\300B\263\331\277\210R\251\277\234\343q\277,\"\021\277\340\202A\276\360\202A>0\"\021?\244\343q?\212R\251?B\263\331?\377\t\005@[:\035@\267j5\300Z:\035\300\376\t\005\300B\263\331\277\210R\251\277\234\343q\
000@\000\000\240@\000\000\260A\000\000D\302\000\000\214\302\000\000dB\000\000\\B\000\000\260A\000\000\350\301\000\000`\302\000\000L\302\000\000\204\302\000\000\300@\000\000@A\000\000\310\301\000\000PA\000\000\340\300\000\000\256B\000\000\350\301\000\000\274\302\000\000\206\302\000\000\260\301\000\000\360\301\000\000\030B\000\000\000\000\000\000@\300\000\000\010B\000\000\220\302\000\000\330A\000\000t\302\000\0000\302\000\000\270A\000\000 B\000\000\340\300\000\000\200?\000\000\360\301\000\000(B\000\000h\302\000\000\300A\000\000\340\300\000\000p\301\000\000\030B\000\000\240B\000\000T\302\000\000,B\000\000\200?\000\000\340@\000\000LB\000\000 \301\000\000\300\301\000\0004B\000\000\370\301\000\000\220\301\000\000\330\301\000\000\000\302\000\000\\B\000\000\370A\000\000\256\302\000\000\210\301\000\000\340\301\000\000\210B\000\000P\301\000\000\250A\000\000\240\301\000\000\370\301\000\000\216\302\000\000\000B\000\000,\302\000\000\240\301\000\000D\302\000\000\340@\000\000\240\301\000\000\226\302\000\000\000\000\000\000\230\301\000\000,B\000\000PA\000\000\206\302\000\000hB\000\000\220\301\000\000\220A\000\000\224\302\000\000$B\000\000(\302\000\000lB\000\000@@\000\000\230\301\000\0004B\000\000<B\000\000\340\301\000\000\310A\000\000\310\302\000\0 ...
#   }
#   initializer {
#     data_type: 1
#     name: "/fc4/export_handler/Constant_1_output_0"
#     raw_data: "k0\201;"
#   }
#   input {
#     name: "inp.1"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 28
#           }
#           dim {
#             dim_value: 28
#           }
#         }
#       }
#     }
#   }
#   output {
#     name: "73"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_param: "Mul73_dim_0"
#           }
#           dim {
#             dim_param: "Mul73_dim_1"
#           }
#         }
#       }
#     }
#   }
#   quantization_annotation {
#     tensor_name: "/fc1/export_handler/Constant_output_0"
#     quant_parameter_tensor_names {
#       key: "finn_datatype"
#       value: "INT8"
#     }
#   }
#   quantization_annotation {
#     tensor_name: "/fc1/export_handler/Constant_1_output_0"
#     quant_parameter_tensor_names {
#       key: "finn_datatype"
#       value: "INT8"
#     }
#   }
#   quantization_annotation {
#     tensor_name: "/fc2/export_handler/Constant_output_0"
#     quant_parameter_tensor_names {
#       key: "finn_datatype"
#       value: "INT8"
#     }
#   }
#   quantization_annotation {
#     tensor_name: "/fc2/export_handler/Constant_1_output_0"
#     quant_parameter_tensor_names {
#       key: "finn_datatype"
#       value: "INT8"
#     }
#   }
#   quantization_annotation {
#     tensor_name: "/fc3/export_handler/Constant_output_0"
#     quant_parameter_tensor_names {
#       key: "finn_datatype"
#       value: "INT8"
#     }
#   }
#   quantization_annotation {
#     tensor_name: "/fc3/export_handler/Constant_1_output_0"
#     quant_parameter_tensor_names {
#       key: "finn_datatype"
#       value: "INT8"
#     }
#   }
#   quantization_annotation {
#     tensor_name: "/fc4/export_handler/Constant_output_0"
#     quant_parameter_tensor_names {
#       key: "finn_datatype"
#       value: "INT8"
#     }
#   }
# }
# opset_import {
#   domain: ""
#   version: 14
# }
# opset_import {
#   domain: "finn.custom_op.general"
#   version: 1
# }
# opset_import {
#   domain: "{DOMAIN_STRING}"
#   version: 1
# }
